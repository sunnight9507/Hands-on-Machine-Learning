# %%
# 구글 드라이버 이용
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# 파일 불러오기 예시
import pandas as pd

pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/test.csv').head(2)

# 이미지 불러오기 예시
# ![](https://drive.google.com/uc?export=view&id=1z6Q2D-cznuPfBSZwd1MhuRxoB-1Bzodq)
# <img src= "https://drive.google.com/uc?export=view&id=1D9FfbEL9ORMLEHMMKZcq0mEd5gCiLhnh" width="400">
# Out:
#    PassengerId  Pclass                              Name  ...    Fare  Cabin  Embarked
# 0          892       3                  Kelly, Mr. James  ...  7.8292    NaN         Q
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  ...  7.0000    NaN         S
#
# [2 rows x 11 columns]

# %% [markdown]
# ## 10.1 생물학적 뉴런에서 인공 뉴런까지
#
# **인공 신경망**(ANN, Aritificial Neural Networks)은 1943년 신경생리학자 Warren McCulloch과 수학자 Walter Pitts가 ['A Logical Calculus of Ideas Immanent In Nervous Activity'](https://pdfs.semanticscholar.org/5272/8a99829792c3272043842455f3a110e841b1.pdf) 처음 소개했으며, 명제 논리(propositional logic)를 사용해 동물 뇌의 생물학적 뉴런이 복잡한 계산을 위해 어떻게 상호작용하는지에 대해 간단한 계산 모델을 제시했다.
#
# 1960년대까지는 이렇게 등장한 인공 신경망을 통해 사람들은 지능을 가진 기계와 대화를 나눌 수 있을 것이라고 생각했다. 하지만 아래 그림(출처: [beamandrew's blog](https://beamandrew.github.io/deeplearning/2017/02/23/deep_learning_101_part1.html))처럼 사람들의 기대와는 달리 인공 신경망으로 `XOR`문제를 해결할 수 없게 되었고, 1990년 대에는 SVM과 성능이 좋은 다른 머신러닝 알고리즘들이 나오게 되면서 인공 신경망은 암흑기로 접어 들게 되었다.
#
#
# 2000년 대에 들어서면서 인공 신경망은 2012년 ILSVRC2012 대회에서 인공 신경망을 깊게 쌓은 딥러닝 모델인 AlexNet이 압도적인 성적으로 우승하면서 다시금 주목받게 되었다. 이렇게 인공 신경망(딥러닝)이 다시 주목받게 된 계기는 다음과 같은 것들이 있다.
#
# - 빅 데이터 시대인 요즘 신경망을 학습시키기 위한 데이터가 엄청나게 많아 졌다.
# - 신경망은 다른 머신러닝 알고리즘보다 규모가 크고 복잡한 문제에서 성능이 좋다.
# - 1990년대 이후 크게 발전된 컴퓨터 하드웨어 성능과 Matrix연산에 고성능인 GPU로 인해 상대적으로 짧은 시간 안에 대규모의 신경망을 학습시킬 수 있게 되었다.

# %% [markdown]
# ### 10.1.1 생물학적 뉴런
#
# - 생물학적 뉴런
#   - 사람의 뇌에서 볼 수 있는 세포로써 핵(nucleus)을 포함하는 **세포체**(cell body)와 구성 요소로 이루어져 있다.
#   - **Dendrite** : 수상돌기, 다른 뉴런으로부터 신호를 수용하는 부분
#   - **Axon** : 축삭돌기, 신호를 내보내는 부분
#   - **Synaptic terminals** : 시냅스(synapse) 뉴런의 접합부, 다른 뉴런으로 부터 짧은 전기 자극 **신호**(signal)를 받음
#
# ![](https://drive.google.com/uc?export=view&id=1sW5uUEB0UaJKlbPqEuzDxDlnfWDAH_yZ)
#
# - 출처 : [wikipedia](https://en.wikipedia.org/wiki/Neuron)

# %% [markdown]
# ### 10.1.2 뉴런을 사용한 논리 연산
#
# 워런 맥컬록과 윌터 피츠는 매우 단순한 생물학적 뉴런 모델을 제안했는데, 나중에 이것이 **인공 뉴런**이 되었다.
#
# 처음 인공 신경망을 제안한  Warren McCulloch과 Walter Pitts의 인공 뉴런 모델은 아래의 그림(출처: 핸즈온-머신러닝)과 같다.
#
# 이 모델은 하나 이상의 이진(`on/off`) 입력과 하나의 출력을 가진다.
#
# ![](https://drive.google.com/uc?export=view&id=1p9XTUj6qeUJA1LIua2XlC1FsnggX_rnj)
#
#
#
# - ①은 항등함수를 의미하며, 뉴런 `A`가 활성화 되면 뉴런 `C` 또한 활성화된다.
# - ②는 논리곱 연산을 의미하며, 뉴런 `A`와 `B`가 모두 활성화될 때만 뉴런 `C`가 활성화된다.
# - ③은 논리합 연산을 의미하며, 뉴런 `A`와 `B` 둘 중 하나라도 활성화되면 `C`가 활성화된다.
# - ④는 어떤 입력이 뉴런의 활성화를 억제할 수 있다고 가정하면, 위의 그림에서 처럼 뉴런 `A`가 활성화 되고 `B`가 비활성화될 때 뉴런 `C`가 활성화된다.

# %% [markdown]
# ### 10.1.3 퍼셉트론
#
# **퍼셉트론**(Perceptron)은 Frank Rosenblatt가 1975년에 제안한 인공 신경망 구조 중 하나이며, 이 퍼셉트론이 바로 신경망(딥러닝)의 기원이 되는 알고리즘이라고 할 수 있다.
#
# 퍼셉트론은 **TLU**(Threshold Logic Unit)이라는 형태의 뉴런을 기반으로 하며, 아래의 그림과 같이 입력과 출력이 어떤 숫자고 각각의 입력에 각각 고유한 **가중치**($\mathbf{W}$, weight)가 곱해진다.
#
# $$
# z = w_1x_1 + w_2x_2 + \cdots + w_nx_n = \mathbf{W}^{T} \cdot \mathbf{X}
# $$
#
# 그런 다음 계산된 합 $z$에 **계단 함수**(step function)를 적용하여 결과 $h$를 출력한다.
#
# $$
# \begin{align*}
# h_w(\mathbf{X}) &= \text{step}(z) \\ &= \text{step}(\mathbf{W}^{T} \cdot \mathbf{X})
# \end{align*}
# $$
#
# <img src= "https://drive.google.com/uc?export=view&id=1D9FfbEL9ORMLEHMMKZcq0mEd5gCiLhnh" width="400">

# %% [markdown]
# **헤비사이드 계단 함수**
#   - 퍼셉트론에서 가장 널리 사용되는 계단 함수
#   - 계단 함수 대신 부호 함수(sign function)을 사용하기도 한다.
# $$
# \text{heaviside}(z)=\begin{cases} 0 \text{  (}z < 0)  \\ 1 \text{  (}z \ge 0) \end{cases}, \quad \text{sgn}(z)= \begin{cases} -1 \text{  (}z < 0)\\ 0 \text{ (}z = 0)\\ +1 \text{  (}z > 0)\end{cases}
# $$
#
# 위의 그림에서 처럼, 하나의 TLU는 입력과 가중치의 선형결합인 $z$가 $z \ge 0$ 이면 양성 클래스, $z < 0$이면 음성 클래스를 출력하게 하는 **선형 이진 분류**(linear binary classification)에 적용할 수 있다.
#
# 아래의 그림은 위의 TLU를 세 개로 구성한 퍼셉트론에 편향($x_0=1$)을 추가한 것이다. 이 퍼셉트론은 샘플 세 개의 클래스(레이블)로 분류할 수 있는 **다중 출력 분류기**(Multioutput Classifier)이다.
#
# <img src = "https://drive.google.com/uc?export=view&id=1wQbwSU6X320GcL2hGGjrzE0u9x0fSWH0" width = "400">

# %% [markdown]
# **헤브 학습**
#   - 서로 활성화되는 세포가 서로 연결된다.
#   - 두 뉴런이 동일한 출력을 낼 때마다 이 둘 사이의 연결 가중치가 증가
#
#
# **퍼셉트론 학습 규칙(가중치 업데이트)**
#
# $$
# w_{i,j}^{\text{(next step)}} = w_{i,j} + \eta \left( y_j - \hat{y}_j \right) x_i
# $$
#
# - $w_{i,j}$ : $i$-번째 입력 뉴런과 $j$-번째 출력 뉴런 사이를 연결하는 가중치
# - $x_i$ : 현재 학습 데이터 샘플의 $i$-번째 뉴런의 입력값
# - $\hat{y}_j$ : 현재 학습 데이터 샘플의 $j$-번째 출력 뉴런의 출력값
# - $y_j$ : 현재 학습 데이터 샘플의 $j$-번째 출력 뉴런의 실제값
#
# **퍼셉트론 수렴 이론**(Perceptron convergence theorem)
#   - Frank Rosenblatt는 학습 데이터가 선형적으로 구분될 수 있으면, 퍼셉트론은 정답에 수렴한다는 것

# %% [markdown]
# #### Scikit-Learn의 Perceptron 클래스
#
# Scikit-Learn은 하나의 TLU 퍼셉트론을 구현한 `Perceptron`클래스를 제공한다.
# 아래의 예제는 iris dataset(붓꽃 데이터셋)에서 꽃잎의 길이(`petal length`)와 너비(`petal width`)를 가지고 붓꽃 종류 중 `Setosa`인지 아닌지를 분류하는 이진 분류기를 구현한 것이다.

# %%
# Google colab 한글 깨질때
# 안될경우 런타임 다시 시작
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

plt.figure(figsize=(5,5))
plt.plot([0,1], [0,1], label='한글테스트용')
plt.legend()
plt.show()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 53580 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 53580 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron
import numpy as np

iris = load_iris()
# 꽃잎의 길이와 너비
X = iris.data[:, (2, 3)]
# Iris sentosa 인지
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(max_iter=100, random_state=42)
per_clf.fit(X, y)

# 1이면 iris sentosa
# 0이면 iris sentosa가 아니다
y_pred = per_clf.predict([[2, 0.5]])
print(y_pred)
# Out:
# [1]

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')
# %matplotlib inline

a = -per_clf.coef_[0][0] / per_clf.coef_[0][1]
b = -per_clf.intercept_ / per_clf.coef_[0][1]

axes = [0, 5, 0, 2]

x0, x1 = np.meshgrid(
        np.linspace(axes[0], axes[1], 500).reshape(-1, 1),
        np.linspace(axes[2], axes[3], 200).reshape(-1, 1),
    )
X_new = np.c_[x0.ravel(), x1.ravel()]
y_predict = per_clf.predict(X_new)
zz = y_predict.reshape(x0.shape)

plt.figure(figsize=(10, 4))
plt.plot(X[y==0, 0], X[y==0, 1], "bs", label="Iris-Setosa 아님")
plt.plot(X[y==1, 0], X[y==1, 1], "yo", label="Iris-Setosa")

plt.plot([axes[0], axes[1]], [a * axes[0] + b, a * axes[1] + b], "k-", linewidth=3)
from matplotlib.colors import ListedColormap
custom_cmap = ListedColormap(['#9898ff', '#fafab0'])

plt.contourf(x0, x1, zz, cmap=custom_cmap)
plt.xlabel("꽃잎 길이", fontsize=14)
plt.ylabel("꽃잎 너비", fontsize=14)
plt.legend(loc="lower right", fontsize=14)
plt.axis(axes)
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #### 퍼셉트론의 약점: XOR 문제
#
# 1969년 Marvin Minsky와 Seymour Papert는 '퍼셉트론'이란 논문에서 퍼셉트론의 심각한 약점이 있다는 것을 보였는데, 그 중에서도 가장 결정적인 것은 선형결합인 퍼셉트론이 배타적 논리합인 XOR 분류 문제를 해결할 수 없다는 것이었다.
#
#
# 이를 계기로 인공 신경망은 암흑기를 맞이하게 되었다. 하지만, 단일 퍼셉트론을 여러개 쌓아 **다층 퍼셉트론**(**MLP**, Multi-Layer Perceptron)을 통해 XOR 분류 문제를 해결할 수 있었다.
#
# <img src = "https://drive.google.com/uc?export=view&id=1TPmHrgEaTzwK4yQokoMQGVDW_CKZf-b0">

# %% [markdown]
# ### 10.1.4 다층 퍼셉트론과 역전파
#
# 다층 퍼셉트론(MLP)은 **입력층**, **은닉층(hidden layer)**이라 부르는 하나 이상의 TLU 층과 마지막으로 **출력층**(output layer)으로 구성된다.
# 인공 신경망의 은닉층이 2개 이상일 때, **심층 신경망**(**DNN**, Deep Neural Network)라 하고 이를 학습하여 모델을 만드는 것을 **딥러닝**(Deep-Learning) 이라고 한다.
#
# 이렇게 여러층을 쌓은 MLP를 통해 XOR 문제를 해결 했지만, 층이 깊어질 수록 증가하는 가중치 매개변수의 수로 인해 다층 퍼셉트론을 학습시키기에는 오랜 시간이 걸리는 문제가 발생했다. 하지만, 1986년 **역전파(backpropogation)** 알고리즘이 등장하면서 계산량을 획기적으로 줄일 수 있게 되었다.
#
#
# - 역전파법
#   1. **순전파** : 각 학습 데이터 샘플을 네트워크에 입력으로 넣어주고 출력층까지 각 층의 뉴런 마다 출력을 계산
#   2. 마지막 출력층에 대한 결과(예측값)와 실제값과의 차이, 즉 오차(error)를 계산하는데, 손실함수(loss function)를 이용해 계산
#   3. 오차를 역방향으로 흘러 보내면서, 각 출력 뉴런의 오차에 마지막 입력 뉴런이 얼마나 기여했는지 측정
#     - **각 뉴런의 입력값에 대한 손실함수의 편미분, 그래디언트(gradient)을 계산**하는 것을 말한다.
#   4. 3번과 같은 방법을 입력층에 도달할 때까지 계속 반복해서 역방향으로 흘러 보낸다.
#   5. 마지막으로, 계산한 그래디언트를 네트워크의 모든 가중치 매개변수에 반영해주는 **경사 하강법 단계**를 수행
#
# 따라서, 먼저 순전파를 통해 네트워크가 예측을 출력(출력층의 출력 결과)하고, 이를 손실함수를 이용해 오차를 계산한 뒤, 역방향으로 거슬러 올라가면서 각 뉴런의 입력값에 대한 손실함수의 편미분을 계산하고(backpropagation), 이를 경사 하강법을 이용해 가중치를 조정하는 방법이 역전파 알고리즘이다.

# %% [markdown]
# #### 활성화 함수 (activation function)
#
# 역전파 알고리즘이 잘 동작하기 위해서 다층 퍼셉트론(MLP)의 구조에 변화를 주었는 데, 그것이 바로 활성화 함수 부분에서 계단 함수를 시그모이드 함수(로지스틱 함수)로 바꿔준 것이다.
#
# 이렇게 활성화 함수를 시그모이드 함수로 바꿔준 이유는 가중치 매개변수를 조정 해주기 위해 그래디언트, 편미분을 계산하게 되는데, 계단 함수는 0을 기준으로 기울기가 없는 직선이므로 그래디언트를 계산하는 것이 의미가 없기 때문이다
#
# 활성화 함수로는 아래의 그림처럼 로지스틱 함수 외에 다양한 활성화 함수를 사용할 수 있다.

# %%
def logit(z):
    return 1 / (1 + np.exp(-z))

def relu(z):
    return np.maximum(0, z)

def derivative(f, z, eps=0.000001):
    return (f(z + eps) - f(z - eps))/(2 * eps)

# %%
z = np.linspace(-5, 5, 200)

plt.figure(figsize=(11,4))

plt.subplot(121)
plt.plot(z, np.sign(z), "r-", linewidth=2, label="스텝")
plt.plot(z, logit(z), "g--", linewidth=2, label="로지스틱")
plt.plot(z, np.tanh(z), "b-", linewidth=2, label="Tanh")
plt.plot(z, relu(z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
plt.legend(loc="center right", fontsize=14)
plt.title("활성화 함수", fontsize=14)
plt.axis([-5, 5, -1.2, 1.2])

plt.subplot(122)
plt.plot(z, derivative(np.sign, z), "r-", linewidth=2, label="Step")
plt.plot(0, 0, "ro", markersize=5)
plt.plot(0, 0, "rx", markersize=10)
plt.plot(z, derivative(logit, z), "g--", linewidth=2, label="Logit")
plt.plot(z, derivative(np.tanh, z), "b-", linewidth=2, label="Tanh")
plt.plot(z, derivative(relu, z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
plt.title("도함수", fontsize=14)
plt.axis([-5, 5, -0.2, 1.2])
plt.show()

# %% [markdown]
# #### 소프트맥스(softmax) 함수
#
# **소프트맥스 함수**(softmax function)는 출력층에서 주로 사용하는 활성화 함수이며, 식은 다음과 같다.
# $$
# \hat{y}_k = \frac{ \text{exp} \left( \mathbf{W}^{T} \cdot \mathbf{x} \right)}{\sum_{j=1}^{K}{\text{exp} \left( \mathbf{W}^{T} \cdot \mathbf{x} \right)}} \quad (K=\text{# of class})
# $$
#
#
# 소프트맥스 함수의 특징은 출력값의 총합이 1이 된다는 것이다. 따라서, 각 출력 뉴런에 대한 소프트맥스의 출력값은 각 클래스에 대응하는 추정 확률값으로 볼 수 있다.

# %% [markdown]
# ## 10.2 텐서플로 고수준 API로 다층 퍼셉트론 학습하기
#
# 텐서플로는 사용자가 쉽게 신경망 모델링을 프로그래밍할 수 있도록 high-level의 API를 제공한다. 대표적인 high-level API로는 `tf.estimator`와 `keras`가 있는데, 이에 대한 자세한 내용은 [여기](http://excelsior-cjh.tistory.com/157?category=940399)에서 참고하면 된다.
#
# 아래의 예제는 `tf.estimator`의 `DNNClassifier` 클래스를 이용해 MNIST 숫자 데이터를 분류하는 DNN을 구현한 것이다.

# %%
import tensorflow as tf

# MNIST Dataset Load!
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# reshape : 28 x 28 -> 784
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

# split validation set
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
# TF Estimator
feature_cols = [tf.feature_column.numeric_column("X", shape=[28 * 28])]
dnn_clf = tf.estimator.DNNClassifier(hidden_units=[300, 100], n_classes=10,
                                     feature_columns=feature_cols)

# input function
input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_train}, y=y_train, num_epochs=40, batch_size=50, shuffle=True)

# training
dnn_clf.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpjzdgrbgs
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpjzdgrbgs', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f45e9cf9f98>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/canned/head.py:437: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpjzdgrbgs/model.ckpt.
# INFO:tensorflow:loss = 114.90223, step = 0
# INFO:tensorflow:global_step/sec: 254.319
# INFO:tensorflow:loss = 6.628414, step = 100 (0.396 sec)
# INFO:tensorflow:global_step/sec: 293.321
# INFO:tensorflow:loss = 13.283603, step = 200 (0.342 sec)
# INFO:tensorflow:global_step/sec: 281.043
# INFO:tensorflow:loss = 6.179435, step = 300 (0.354 sec)
# INFO:tensorflow:global_step/sec: 274.692
# INFO:tensorflow:loss = 8.553013, step = 400 (0.366 sec)
# INFO:tensorflow:global_step/sec: 294.468
# INFO:tensorflow:loss = 14.485334, step = 500 (0.339 sec)
# INFO:tensorflow:global_step/sec: 235.521
# INFO:tensorflow:loss = 11.002579, step = 600 (0.426 sec)
# INFO:tensorflow:global_step/sec: 233.333
# INFO:tensorflow:loss = 2.5709498, step = 700 (0.428 sec)
# INFO:tensorflow:global_step/sec: 304.712
# INFO:tensorflow:loss = 4.139695, step = 800 (0.328 sec)
# INFO:tensorflow:global_step/sec: 284.857
# INFO:tensorflow:loss = 6.2252502, step = 900 (0.349 sec)
# INFO:tensorflow:global_step/sec: 263.949
# INFO:tensorflow:loss = 13.152785, step = 1000 (0.380 sec)
# INFO:tensorflow:global_step/sec: 290.076
# INFO:tensorflow:loss = 5.3863935, step = 1100 (0.344 sec)
# INFO:tensorflow:global_step/sec: 272.872
# INFO:tensorflow:loss = 7.4206758, step = 1200 (0.367 sec)
# INFO:tensorflow:global_step/sec: 284.388
# INFO:tensorflow:loss = 8.2243185, step = 1300 (0.353 sec)
# INFO:tensorflow:global_step/sec: 286.608
# INFO:tensorflow:loss = 1.5906022, step = 1400 (0.350 sec)
# INFO:tensorflow:global_step/sec: 270.955
# INFO:tensorflow:loss = 5.79111, step = 1500 (0.367 sec)
# INFO:tensorflow:global_step/sec: 292.349
# INFO:tensorflow:loss = 7.454907, step = 1600 (0.343 sec)
# INFO:tensorflow:global_step/sec: 295.503
# INFO:tensorflow:loss = 2.129226, step = 1700 (0.337 sec)
# INFO:tensorflow:global_step/sec: 271.404
# INFO:tensorflow:loss = 3.907116, step = 1800 (0.369 sec)
# INFO:tensorflow:global_step/sec: 308.762
# INFO:tensorflow:loss = 1.4020079, step = 1900 (0.324 sec)
# INFO:tensorflow:global_step/sec: 277.596
# INFO:tensorflow:loss = 3.0608766, step = 2000 (0.362 sec)
# INFO:tensorflow:global_step/sec: 285.238
# INFO:tensorflow:loss = 8.227894, step = 2100 (0.351 sec)
# INFO:tensorflow:global_step/sec: 281.932
# INFO:tensorflow:loss = 4.7756424, step = 2200 (0.354 sec)
# INFO:tensorflow:global_step/sec: 305.855
# INFO:tensorflow:loss = 0.3657274, step = 2300 (0.326 sec)
# INFO:tensorflow:global_step/sec: 286.498
# INFO:tensorflow:loss = 2.9913445, step = 2400 (0.349 sec)
# INFO:tensorflow:global_step/sec: 286.129
# INFO:tensorflow:loss = 3.703679, step = 2500 (0.349 sec)
# INFO:tensorflow:global_step/sec: 303.136
# INFO:tensorflow:loss = 1.6758871, step = 2600 (0.330 sec)
# INFO:tensorflow:global_step/sec: 276.985
# INFO:tensorflow:loss = 0.65900224, step = 2700 (0.363 sec)
# INFO:tensorflow:global_step/sec: 284.902
# INFO:tensorflow:loss = 1.921579, step = 2800 (0.351 sec)
# INFO:tensorflow:global_step/sec: 292.014
# INFO:tensorflow:loss = 2.5986404, step = 2900 (0.341 sec)
# INFO:tensorflow:global_step/sec: 289.467
# INFO:tensorflow:loss = 3.1402864, step = 3000 (0.346 sec)
# INFO:tensorflow:global_step/sec: 282.544
# INFO:tensorflow:loss = 0.60000914, step = 3100 (0.354 sec)
# INFO:tensorflow:global_step/sec: 302.285
# INFO:tensorflow:loss = 1.9503047, step = 3200 (0.330 sec)
# INFO:tensorflow:global_step/sec: 290.465
# INFO:tensorflow:loss = 4.7823133, step = 3300 (0.345 sec)
# INFO:tensorflow:global_step/sec: 293.073
# INFO:tensorflow:loss = 1.1615973, step = 3400 (0.342 sec)
# INFO:tensorflow:global_step/sec: 302.285
# INFO:tensorflow:loss = 2.1181364, step = 3500 (0.328 sec)
# INFO:tensorflow:global_step/sec: 290.211
# INFO:tensorflow:loss = 1.7022454, step = 3600 (0.345 sec)
# INFO:tensorflow:global_step/sec: 259.603
# INFO:tensorflow:loss = 0.5889617, step = 3700 (0.385 sec)
# INFO:tensorflow:global_step/sec: 297.68
# INFO:tensorflow:loss = 0.5943049, step = 3800 (0.338 sec)
# INFO:tensorflow:global_step/sec: 275.979
# INFO:tensorflow:loss = 3.902339, step = 3900 (0.363 sec)
# INFO:tensorflow:global_step/sec: 296.455
# INFO:tensorflow:loss = 6.176518, step = 4000 (0.337 sec)
# INFO:tensorflow:global_step/sec: 281.537
# INFO:tensorflow:loss = 0.6146052, step = 4100 (0.356 sec)
# INFO:tensorflow:global_step/sec: 306.442
# INFO:tensorflow:loss = 0.4595508, step = 4200 (0.325 sec)
# INFO:tensorflow:global_step/sec: 284.261
# INFO:tensorflow:loss = 3.9000993, step = 4300 (0.350 sec)
# INFO:tensorflow:global_step/sec: 291.702
# INFO:tensorflow:loss = 2.7174764, step = 4400 (0.343 sec)
# INFO:tensorflow:global_step/sec: 304.812
# INFO:tensorflow:loss = 2.4790854, step = 4500 (0.328 sec)
# INFO:tensorflow:global_step/sec: 286.609
# INFO:tensorflow:loss = 0.6419168, step = 4600 (0.348 sec)
# INFO:tensorflow:global_step/sec: 283.589
# INFO:tensorflow:loss = 1.1060933, step = 4700 (0.354 sec)
# INFO:tensorflow:global_step/sec: 290.799
# INFO:tensorflow:loss = 0.7015508, step = 4800 (0.342 sec)
# INFO:tensorflow:global_step/sec: 298.093
# INFO:tensorflow:loss = 1.1692121, step = 4900 (0.335 sec)
# INFO:tensorflow:global_step/sec: 294.542
# INFO:tensorflow:loss = 2.939228, step = 5000 (0.340 sec)
# INFO:tensorflow:global_step/sec: 313.267
# INFO:tensorflow:loss = 0.53785914, step = 5100 (0.319 sec)
# INFO:tensorflow:global_step/sec: 294.486
# INFO:tensorflow:loss = 2.6815, step = 5200 (0.341 sec)
# INFO:tensorflow:global_step/sec: 277.521
# INFO:tensorflow:loss = 0.42430276, step = 5300 (0.359 sec)
# INFO:tensorflow:global_step/sec: 304.027
# INFO:tensorflow:loss = 0.61997116, step = 5400 (0.329 sec)
# INFO:tensorflow:global_step/sec: 285.243
# INFO:tensorflow:loss = 5.2106924, step = 5500 (0.351 sec)
# INFO:tensorflow:global_step/sec: 298.331
# INFO:tensorflow:loss = 0.2935042, step = 5600 (0.337 sec)
# INFO:tensorflow:global_step/sec: 292.113
# INFO:tensorflow:loss = 0.5395007, step = 5700 (0.340 sec)
# INFO:tensorflow:global_step/sec: 283.823
# INFO:tensorflow:loss = 0.4720241, step = 5800 (0.356 sec)
# INFO:tensorflow:global_step/sec: 279.17
# INFO:tensorflow:loss = 0.19596931, step = 5900 (0.357 sec)
# INFO:tensorflow:global_step/sec: 298.628
# INFO:tensorflow:loss = 0.09198813, step = 6000 (0.334 sec)
# INFO:tensorflow:global_step/sec: 274.836
# INFO:tensorflow:loss = 1.199994, step = 6100 (0.365 sec)
# INFO:tensorflow:global_step/sec: 296.975
# INFO:tensorflow:loss = 4.3961053, step = 6200 (0.335 sec)
# INFO:tensorflow:global_step/sec: 302.866
# INFO:tensorflow:loss = 0.7371656, step = 6300 (0.328 sec)
# INFO:tensorflow:global_step/sec: 299.441
# INFO:tensorflow:loss = 0.50522244, step = 6400 (0.335 sec)
# INFO:tensorflow:global_step/sec: 287.903
# INFO:tensorflow:loss = 0.51846945, step = 6500 (0.346 sec)
# INFO:tensorflow:global_step/sec: 304.8
# INFO:tensorflow:loss = 0.7765313, step = 6600 (0.328 sec)
# INFO:tensorflow:global_step/sec: 313.38
# INFO:tensorflow:loss = 1.0459964, step = 6700 (0.319 sec)
# INFO:tensorflow:global_step/sec: 294.855
# INFO:tensorflow:loss = 0.5574307, step = 6800 (0.339 sec)
# INFO:tensorflow:global_step/sec: 307.675
# INFO:tensorflow:loss = 0.47622097, step = 6900 (0.325 sec)
# INFO:tensorflow:global_step/sec: 298.986
# INFO:tensorflow:loss = 0.092625126, step = 7000 (0.336 sec)
# INFO:tensorflow:global_step/sec: 284.509
# INFO:tensorflow:loss = 0.08853336, step = 7100 (0.351 sec)
# INFO:tensorflow:global_step/sec: 330.202
# INFO:tensorflow:loss = 0.36175683, step = 7200 (0.302 sec)
# INFO:tensorflow:global_step/sec: 318.522
# INFO:tensorflow:loss = 0.905958, step = 7300 (0.313 sec)
# INFO:tensorflow:global_step/sec: 309.511
# INFO:tensorflow:loss = 0.22265194, step = 7400 (0.323 sec)
# INFO:tensorflow:global_step/sec: 300.879
# INFO:tensorflow:loss = 0.48787093, step = 7500 (0.335 sec)
# INFO:tensorflow:global_step/sec: 300.263
# INFO:tensorflow:loss = 0.7259665, step = 7600 (0.333 sec)
# INFO:tensorflow:global_step/sec: 307.438
# INFO:tensorflow:loss = 0.9145473, step = 7700 (0.323 sec)
# INFO:tensorflow:global_step/sec: 303.994
# INFO:tensorflow:loss = 1.124858, step = 7800 (0.328 sec)
# INFO:tensorflow:global_step/sec: 308.968
# INFO:tensorflow:loss = 0.3746726, step = 7900 (0.323 sec)
# INFO:tensorflow:global_step/sec: 311.236
# INFO:tensorflow:loss = 1.2018704, step = 8000 (0.323 sec)
# INFO:tensorflow:global_step/sec: 292.649
# INFO:tensorflow:loss = 0.53607035, step = 8100 (0.343 sec)
# INFO:tensorflow:global_step/sec: 309.607
# INFO:tensorflow:loss = 0.3705706, step = 8200 (0.320 sec)
# INFO:tensorflow:global_step/sec: 293.502
# INFO:tensorflow:loss = 0.7004114, step = 8300 (0.343 sec)
# INFO:tensorflow:global_step/sec: 298.791
# INFO:tensorflow:loss = 0.7498533, step = 8400 (0.332 sec)
# INFO:tensorflow:global_step/sec: 294.161
# INFO:tensorflow:loss = 0.2855165, step = 8500 (0.340 sec)
# INFO:tensorflow:global_step/sec: 321.198
# INFO:tensorflow:loss = 0.140414, step = 8600 (0.311 sec)
# INFO:tensorflow:global_step/sec: 285.065
# INFO:tensorflow:loss = 2.313054, step = 8700 (0.353 sec)
# INFO:tensorflow:global_step/sec: 321.076
# INFO:tensorflow:loss = 1.30926, step = 8800 (0.310 sec)
# INFO:tensorflow:global_step/sec: 308.341
# INFO:tensorflow:loss = 0.060611825, step = 8900 (0.324 sec)
# INFO:tensorflow:global_step/sec: 274.865
# INFO:tensorflow:loss = 0.144501, step = 9000 (0.365 sec)
# INFO:tensorflow:global_step/sec: 300.293
# INFO:tensorflow:loss = 0.17769158, step = 9100 (0.332 sec)
# INFO:tensorflow:global_step/sec: 315.734
# INFO:tensorflow:loss = 0.26831838, step = 9200 (0.316 sec)
# INFO:tensorflow:global_step/sec: 293.913
# INFO:tensorflow:loss = 0.07214728, step = 9300 (0.341 sec)
# INFO:tensorflow:global_step/sec: 317.279
# INFO:tensorflow:loss = 0.2902654, step = 9400 (0.315 sec)
# INFO:tensorflow:global_step/sec: 281.759
# INFO:tensorflow:loss = 4.139104, step = 9500 (0.355 sec)
# INFO:tensorflow:global_step/sec: 301.866
# INFO:tensorflow:loss = 0.4838208, step = 9600 (0.332 sec)
# INFO:tensorflow:global_step/sec: 300.483
# INFO:tensorflow:loss = 2.618228, step = 9700 (0.335 sec)
# INFO:tensorflow:global_step/sec: 295.779
# INFO:tensorflow:loss = 0.46712482, step = 9800 (0.337 sec)
# INFO:tensorflow:global_step/sec: 310.511
# INFO:tensorflow:loss = 0.9026465, step = 9900 (0.320 sec)
# INFO:tensorflow:global_step/sec: 299.525
# INFO:tensorflow:loss = 1.6728007, step = 10000 (0.333 sec)
# INFO:tensorflow:global_step/sec: 308.483
# INFO:tensorflow:loss = 0.64265823, step = 10100 (0.327 sec)
# INFO:tensorflow:global_step/sec: 281.587
# INFO:tensorflow:loss = 0.08476739, step = 10200 (0.355 sec)
# INFO:tensorflow:global_step/sec: 289.69
# INFO:tensorflow:loss = 0.07421607, step = 10300 (0.346 sec)
# INFO:tensorflow:global_step/sec: 307.456
# INFO:tensorflow:loss = 0.08790201, step = 10400 (0.325 sec)
# INFO:tensorflow:global_step/sec: 308.767
# INFO:tensorflow:loss = 0.032209318, step = 10500 (0.324 sec)
# INFO:tensorflow:global_step/sec: 300.634
# INFO:tensorflow:loss = 0.29488462, step = 10600 (0.331 sec)
# INFO:tensorflow:global_step/sec: 272.028
# INFO:tensorflow:loss = 0.3806978, step = 10700 (0.368 sec)
# INFO:tensorflow:global_step/sec: 287.901
# INFO:tensorflow:loss = 0.18311314, step = 10800 (0.348 sec)
# INFO:tensorflow:global_step/sec: 286.435
# INFO:tensorflow:loss = 0.19061321, step = 10900 (0.346 sec)
# INFO:tensorflow:global_step/sec: 301.286
# INFO:tensorflow:loss = 0.6183453, step = 11000 (0.332 sec)
# INFO:tensorflow:global_step/sec: 296.733
# INFO:tensorflow:loss = 0.06313431, step = 11100 (0.338 sec)
# INFO:tensorflow:global_step/sec: 299.371
# INFO:tensorflow:loss = 0.38193327, step = 11200 (0.334 sec)
# INFO:tensorflow:global_step/sec: 314.801
# INFO:tensorflow:loss = 0.16179015, step = 11300 (0.319 sec)
# INFO:tensorflow:global_step/sec: 288.629
# INFO:tensorflow:loss = 0.40012342, step = 11400 (0.343 sec)
# INFO:tensorflow:global_step/sec: 306.677
# INFO:tensorflow:loss = 0.29761574, step = 11500 (0.326 sec)
# INFO:tensorflow:global_step/sec: 307.992
# INFO:tensorflow:loss = 0.21045244, step = 11600 (0.325 sec)
# INFO:tensorflow:global_step/sec: 312.784
# INFO:tensorflow:loss = 3.8546302, step = 11700 (0.321 sec)
# INFO:tensorflow:global_step/sec: 294.417
# INFO:tensorflow:loss = 0.63772714, step = 11800 (0.341 sec)
# INFO:tensorflow:global_step/sec: 303.24
# INFO:tensorflow:loss = 0.18310553, step = 11900 (0.329 sec)
# INFO:tensorflow:global_step/sec: 315.447
# INFO:tensorflow:loss = 0.77993894, step = 12000 (0.315 sec)
# INFO:tensorflow:global_step/sec: 298.397
# INFO:tensorflow:loss = 0.2589165, step = 12100 (0.336 sec)
# INFO:tensorflow:global_step/sec: 309.105
# INFO:tensorflow:loss = 0.15545836, step = 12200 (0.323 sec)
# INFO:tensorflow:global_step/sec: 321.406
# INFO:tensorflow:loss = 0.087886296, step = 12300 (0.310 sec)
# INFO:tensorflow:global_step/sec: 305.995
# INFO:tensorflow:loss = 0.15482855, step = 12400 (0.328 sec)
# INFO:tensorflow:global_step/sec: 303.364
# INFO:tensorflow:loss = 0.901033, step = 12500 (0.331 sec)
# INFO:tensorflow:global_step/sec: 306.623
# INFO:tensorflow:loss = 0.22624907, step = 12600 (0.325 sec)
# INFO:tensorflow:global_step/sec: 283.932
# INFO:tensorflow:loss = 0.14863089, step = 12700 (0.352 sec)
# INFO:tensorflow:global_step/sec: 303.819
# INFO:tensorflow:loss = 3.235206, step = 12800 (0.329 sec)
# INFO:tensorflow:global_step/sec: 312.078
# INFO:tensorflow:loss = 0.16805375, step = 12900 (0.321 sec)
# INFO:tensorflow:global_step/sec: 305.374
# INFO:tensorflow:loss = 0.1395728, step = 13000 (0.326 sec)
# INFO:tensorflow:global_step/sec: 313.439
# INFO:tensorflow:loss = 0.3389069, step = 13100 (0.319 sec)
# INFO:tensorflow:global_step/sec: 303.616
# INFO:tensorflow:loss = 0.20216976, step = 13200 (0.330 sec)
# INFO:tensorflow:global_step/sec: 307.241
# INFO:tensorflow:loss = 0.21191528, step = 13300 (0.328 sec)
# INFO:tensorflow:global_step/sec: 287.409
# INFO:tensorflow:loss = 1.0761101, step = 13400 (0.347 sec)
# INFO:tensorflow:global_step/sec: 298.188
# INFO:tensorflow:loss = 0.10970338, step = 13500 (0.334 sec)
# INFO:tensorflow:global_step/sec: 301.028
# INFO:tensorflow:loss = 0.13398187, step = 13600 (0.332 sec)
# INFO:tensorflow:global_step/sec: 298.367
# INFO:tensorflow:loss = 0.76512694, step = 13700 (0.336 sec)
# INFO:tensorflow:global_step/sec: 287.027
# INFO:tensorflow:loss = 0.024805933, step = 13800 (0.348 sec)
# INFO:tensorflow:global_step/sec: 312.122
# INFO:tensorflow:loss = 0.11146261, step = 13900 (0.321 sec)
# INFO:tensorflow:global_step/sec: 308.108
# INFO:tensorflow:loss = 0.2292004, step = 14000 (0.324 sec)
# INFO:tensorflow:global_step/sec: 290.319
# INFO:tensorflow:loss = 0.062162593, step = 14100 (0.344 sec)
# INFO:tensorflow:global_step/sec: 309.775
# INFO:tensorflow:loss = 0.69242585, step = 14200 (0.323 sec)
# INFO:tensorflow:global_step/sec: 303.722
# INFO:tensorflow:loss = 0.099367775, step = 14300 (0.331 sec)
# INFO:tensorflow:global_step/sec: 310.336
# INFO:tensorflow:loss = 0.11281417, step = 14400 (0.322 sec)
# INFO:tensorflow:global_step/sec: 307.658
# INFO:tensorflow:loss = 0.21098612, step = 14500 (0.323 sec)
# INFO:tensorflow:global_step/sec: 310.112
# INFO:tensorflow:loss = 0.46670404, step = 14600 (0.323 sec)
# INFO:tensorflow:global_step/sec: 322.594
# INFO:tensorflow:loss = 0.06791203, step = 14700 (0.310 sec)
# INFO:tensorflow:global_step/sec: 313.625
# INFO:tensorflow:loss = 0.21557347, step = 14800 (0.319 sec)
# INFO:tensorflow:global_step/sec: 301.572
# INFO:tensorflow:loss = 0.1424379, step = 14900 (0.331 sec)
# INFO:tensorflow:global_step/sec: 305.775
# INFO:tensorflow:loss = 0.016276965, step = 15000 (0.327 sec)
# INFO:tensorflow:global_step/sec: 286.375
# INFO:tensorflow:loss = 0.050323263, step = 15100 (0.350 sec)
# INFO:tensorflow:global_step/sec: 304.726
# INFO:tensorflow:loss = 0.1570507, step = 15200 (0.329 sec)
# INFO:tensorflow:global_step/sec: 230.382
# INFO:tensorflow:loss = 0.018632714, step = 15300 (0.433 sec)
# INFO:tensorflow:global_step/sec: 266.243
# INFO:tensorflow:loss = 0.21936974, step = 15400 (0.377 sec)
# INFO:tensorflow:global_step/sec: 307.218
# INFO:tensorflow:loss = 0.1724874, step = 15500 (0.325 sec)
# INFO:tensorflow:global_step/sec: 308.605
# INFO:tensorflow:loss = 0.0014305247, step = 15600 (0.323 sec)
# INFO:tensorflow:global_step/sec: 285.118
# INFO:tensorflow:loss = 0.011467401, step = 15700 (0.351 sec)
# INFO:tensorflow:global_step/sec: 300.913
# INFO:tensorflow:loss = 0.6604828, step = 15800 (0.332 sec)
# INFO:tensorflow:global_step/sec: 306.403
# INFO:tensorflow:loss = 0.27255318, step = 15900 (0.328 sec)
# INFO:tensorflow:global_step/sec: 291.73
# INFO:tensorflow:loss = 0.02377638, step = 16000 (0.343 sec)
# INFO:tensorflow:global_step/sec: 312.022
# INFO:tensorflow:loss = 0.37096363, step = 16100 (0.318 sec)
# INFO:tensorflow:global_step/sec: 309.68
# INFO:tensorflow:loss = 0.016436081, step = 16200 (0.323 sec)
# INFO:tensorflow:global_step/sec: 300.496
# INFO:tensorflow:loss = 0.07467766, step = 16300 (0.334 sec)
# INFO:tensorflow:global_step/sec: 296.337
# INFO:tensorflow:loss = 0.0863305, step = 16400 (0.337 sec)
# INFO:tensorflow:global_step/sec: 292.147
# INFO:tensorflow:loss = 0.35300577, step = 16500 (0.342 sec)
# INFO:tensorflow:global_step/sec: 303.173
# INFO:tensorflow:loss = 0.107875615, step = 16600 (0.329 sec)
# INFO:tensorflow:global_step/sec: 292.505
# INFO:tensorflow:loss = 0.097870044, step = 16700 (0.342 sec)
# INFO:tensorflow:global_step/sec: 272.397
# INFO:tensorflow:loss = 0.13139334, step = 16800 (0.368 sec)
# INFO:tensorflow:global_step/sec: 232.093
# INFO:tensorflow:loss = 0.116231084, step = 16900 (0.433 sec)
# INFO:tensorflow:global_step/sec: 313.883
# INFO:tensorflow:loss = 0.24673021, step = 17000 (0.319 sec)
# INFO:tensorflow:global_step/sec: 305.335
# INFO:tensorflow:loss = 0.10325462, step = 17100 (0.328 sec)
# INFO:tensorflow:global_step/sec: 293.233
# INFO:tensorflow:loss = 0.38519776, step = 17200 (0.339 sec)
# INFO:tensorflow:global_step/sec: 300.397
# INFO:tensorflow:loss = 0.063351706, step = 17300 (0.331 sec)
# INFO:tensorflow:global_step/sec: 294.638
# INFO:tensorflow:loss = 0.0727271, step = 17400 (0.340 sec)
# INFO:tensorflow:global_step/sec: 307.388
# INFO:tensorflow:loss = 0.023741303, step = 17500 (0.327 sec)
# INFO:tensorflow:global_step/sec: 302.751
# INFO:tensorflow:loss = 0.04795377, step = 17600 (0.331 sec)
# INFO:tensorflow:global_step/sec: 318.972
# INFO:tensorflow:loss = 0.06711686, step = 17700 (0.311 sec)
# INFO:tensorflow:global_step/sec: 311.825
# INFO:tensorflow:loss = 0.08587744, step = 17800 (0.321 sec)
# INFO:tensorflow:global_step/sec: 294.867
# INFO:tensorflow:loss = 0.0018745211, step = 17900 (0.338 sec)
# INFO:tensorflow:global_step/sec: 323.821
# INFO:tensorflow:loss = 0.1264776, step = 18000 (0.309 sec)
# INFO:tensorflow:global_step/sec: 328.019
# INFO:tensorflow:loss = 0.10544179, step = 18100 (0.305 sec)
# INFO:tensorflow:global_step/sec: 300.077
# INFO:tensorflow:loss = 0.34726647, step = 18200 (0.336 sec)
# INFO:tensorflow:global_step/sec: 290.177
# INFO:tensorflow:loss = 0.43376756, step = 18300 (0.345 sec)
# INFO:tensorflow:global_step/sec: 231.754
# INFO:tensorflow:loss = 0.08532495, step = 18400 (0.428 sec)
# INFO:tensorflow:global_step/sec: 273.664
# INFO:tensorflow:loss = 0.22712208, step = 18500 (0.368 sec)
# INFO:tensorflow:global_step/sec: 315.243
# INFO:tensorflow:loss = 0.07592191, step = 18600 (0.316 sec)
# INFO:tensorflow:global_step/sec: 321.048
# INFO:tensorflow:loss = 0.13382974, step = 18700 (0.311 sec)
# INFO:tensorflow:global_step/sec: 294.061
# INFO:tensorflow:loss = 0.040715266, step = 18800 (0.340 sec)
# INFO:tensorflow:global_step/sec: 313.246
# INFO:tensorflow:loss = 0.01320651, step = 18900 (0.319 sec)
# INFO:tensorflow:global_step/sec: 306.939
# INFO:tensorflow:loss = 0.14459068, step = 19000 (0.326 sec)
# INFO:tensorflow:global_step/sec: 288.674
# INFO:tensorflow:loss = 0.07382547, step = 19100 (0.349 sec)
# INFO:tensorflow:global_step/sec: 300.512
# INFO:tensorflow:loss = 0.054493062, step = 19200 (0.332 sec)
# INFO:tensorflow:global_step/sec: 307.627
# INFO:tensorflow:loss = 0.01846592, step = 19300 (0.323 sec)
# INFO:tensorflow:global_step/sec: 291.109
# INFO:tensorflow:loss = 0.104097195, step = 19400 (0.346 sec)
# INFO:tensorflow:global_step/sec: 310.293
# INFO:tensorflow:loss = 0.010348085, step = 19500 (0.323 sec)
# INFO:tensorflow:global_step/sec: 273.599
# INFO:tensorflow:loss = 0.02343972, step = 19600 (0.366 sec)
# INFO:tensorflow:global_step/sec: 273.609
# INFO:tensorflow:loss = 0.08518022, step = 19700 (0.363 sec)
# INFO:tensorflow:global_step/sec: 278.644
# INFO:tensorflow:loss = 0.045728892, step = 19800 (0.359 sec)
# INFO:tensorflow:global_step/sec: 309.756
# INFO:tensorflow:loss = 0.16134861, step = 19900 (0.325 sec)
# INFO:tensorflow:global_step/sec: 289.417
# INFO:tensorflow:loss = 0.026198108, step = 20000 (0.343 sec)
# INFO:tensorflow:global_step/sec: 302.79
# INFO:tensorflow:loss = 0.030621499, step = 20100 (0.330 sec)
# INFO:tensorflow:global_step/sec: 309.904
# INFO:tensorflow:loss = 0.06493491, step = 20200 (0.323 sec)
# INFO:tensorflow:global_step/sec: 284.129
# INFO:tensorflow:loss = 0.018300006, step = 20300 (0.351 sec)
# INFO:tensorflow:global_step/sec: 309.051
# INFO:tensorflow:loss = 0.036314096, step = 20400 (0.324 sec)
# INFO:tensorflow:global_step/sec: 310.651
# INFO:tensorflow:loss = 0.004262021, step = 20500 (0.324 sec)
# INFO:tensorflow:global_step/sec: 298.424
# INFO:tensorflow:loss = 0.048738346, step = 20600 (0.335 sec)
# INFO:tensorflow:global_step/sec: 291.122
# INFO:tensorflow:loss = 0.005591494, step = 20700 (0.344 sec)
# INFO:tensorflow:global_step/sec: 323.115
# INFO:tensorflow:loss = 0.06644517, step = 20800 (0.307 sec)
# INFO:tensorflow:global_step/sec: 307.429
# INFO:tensorflow:loss = 0.0066460213, step = 20900 (0.327 sec)
# INFO:tensorflow:global_step/sec: 300.244
# INFO:tensorflow:loss = 0.050475575, step = 21000 (0.335 sec)
# INFO:tensorflow:global_step/sec: 314.567
# INFO:tensorflow:loss = 0.0323017, step = 21100 (0.318 sec)
# INFO:tensorflow:global_step/sec: 304.514
# INFO:tensorflow:loss = 0.04646553, step = 21200 (0.328 sec)
# INFO:tensorflow:global_step/sec: 311.135
# INFO:tensorflow:loss = 0.031820603, step = 21300 (0.322 sec)
# INFO:tensorflow:global_step/sec: 313.698
# INFO:tensorflow:loss = 0.0019981756, step = 21400 (0.316 sec)
# INFO:tensorflow:global_step/sec: 318.579
# INFO:tensorflow:loss = 0.053289503, step = 21500 (0.314 sec)
# INFO:tensorflow:global_step/sec: 291.86
# INFO:tensorflow:loss = 0.05114745, step = 21600 (0.345 sec)
# INFO:tensorflow:global_step/sec: 299.98
# INFO:tensorflow:loss = 0.10781945, step = 21700 (0.333 sec)
# INFO:tensorflow:global_step/sec: 293.026
# INFO:tensorflow:loss = 0.014977621, step = 21800 (0.339 sec)
# INFO:tensorflow:global_step/sec: 307.317
# INFO:tensorflow:loss = 0.16325216, step = 21900 (0.328 sec)
# INFO:tensorflow:global_step/sec: 295.236
# INFO:tensorflow:loss = 0.16608374, step = 22000 (0.338 sec)
# INFO:tensorflow:global_step/sec: 310.549
# INFO:tensorflow:loss = 0.047936328, step = 22100 (0.322 sec)
# INFO:tensorflow:global_step/sec: 320.386
# INFO:tensorflow:loss = 0.025244359, step = 22200 (0.313 sec)
# INFO:tensorflow:global_step/sec: 297.207
# INFO:tensorflow:loss = 0.04805109, step = 22300 (0.336 sec)
# INFO:tensorflow:global_step/sec: 312.046
# INFO:tensorflow:loss = 0.062729314, step = 22400 (0.319 sec)
# INFO:tensorflow:global_step/sec: 302.081
# INFO:tensorflow:loss = 0.124411725, step = 22500 (0.331 sec)
# INFO:tensorflow:global_step/sec: 306.508
# INFO:tensorflow:loss = 0.07918161, step = 22600 (0.326 sec)
# INFO:tensorflow:global_step/sec: 299.026
# INFO:tensorflow:loss = 0.25936863, step = 22700 (0.337 sec)
# INFO:tensorflow:global_step/sec: 282.448
# INFO:tensorflow:loss = 0.07030766, step = 22800 (0.354 sec)
# INFO:tensorflow:global_step/sec: 300.09
# INFO:tensorflow:loss = 0.011866401, step = 22900 (0.331 sec)
# INFO:tensorflow:global_step/sec: 311.161
# INFO:tensorflow:loss = 0.02029654, step = 23000 (0.322 sec)
# INFO:tensorflow:global_step/sec: 297.126
# INFO:tensorflow:loss = 0.0017646874, step = 23100 (0.340 sec)
# INFO:tensorflow:global_step/sec: 295.308
# INFO:tensorflow:loss = 0.0616704, step = 23200 (0.338 sec)
# INFO:tensorflow:global_step/sec: 299.774
# INFO:tensorflow:loss = 0.056666773, step = 23300 (0.334 sec)
# INFO:tensorflow:global_step/sec: 293.115
# INFO:tensorflow:loss = 0.019342164, step = 23400 (0.339 sec)
# INFO:tensorflow:global_step/sec: 308.408
# INFO:tensorflow:loss = 0.023280784, step = 23500 (0.326 sec)
# INFO:tensorflow:global_step/sec: 318.657
# INFO:tensorflow:loss = 0.019579433, step = 23600 (0.311 sec)
# INFO:tensorflow:global_step/sec: 293.591
# INFO:tensorflow:loss = 0.02692776, step = 23700 (0.341 sec)
# INFO:tensorflow:global_step/sec: 318.846
# INFO:tensorflow:loss = 0.028565655, step = 23800 (0.316 sec)
# INFO:tensorflow:global_step/sec: 293.061
# INFO:tensorflow:loss = 0.009665758, step = 23900 (0.342 sec)
# INFO:tensorflow:global_step/sec: 297.58
# INFO:tensorflow:loss = 0.0219679, step = 24000 (0.333 sec)
# INFO:tensorflow:global_step/sec: 280.701
# INFO:tensorflow:loss = 0.08968936, step = 24100 (0.356 sec)
# INFO:tensorflow:global_step/sec: 307.235
# INFO:tensorflow:loss = 0.08925582, step = 24200 (0.326 sec)
# INFO:tensorflow:global_step/sec: 311.751
# INFO:tensorflow:loss = 0.04323367, step = 24300 (0.324 sec)
# INFO:tensorflow:global_step/sec: 314.404
# INFO:tensorflow:loss = 0.01967806, step = 24400 (0.318 sec)
# INFO:tensorflow:global_step/sec: 299.581
# INFO:tensorflow:loss = 0.12708278, step = 24500 (0.333 sec)
# INFO:tensorflow:global_step/sec: 294.623
# INFO:tensorflow:loss = 0.019466495, step = 24600 (0.340 sec)
# INFO:tensorflow:global_step/sec: 304.755
# INFO:tensorflow:loss = 0.015187487, step = 24700 (0.328 sec)
# INFO:tensorflow:global_step/sec: 305.756
# INFO:tensorflow:loss = 0.14338088, step = 24800 (0.327 sec)
# INFO:tensorflow:global_step/sec: 305.106
# INFO:tensorflow:loss = 0.040414125, step = 24900 (0.327 sec)
# INFO:tensorflow:global_step/sec: 306.744
# INFO:tensorflow:loss = 0.022633456, step = 25000 (0.324 sec)
# INFO:tensorflow:global_step/sec: 303.796
# INFO:tensorflow:loss = 0.067290455, step = 25100 (0.330 sec)
# INFO:tensorflow:global_step/sec: 296.191
# INFO:tensorflow:loss = 0.06982929, step = 25200 (0.339 sec)
# INFO:tensorflow:global_step/sec: 298.079
# INFO:tensorflow:loss = 0.039907135, step = 25300 (0.333 sec)
# INFO:tensorflow:global_step/sec: 313.692
# INFO:tensorflow:loss = 0.043157578, step = 25400 (0.319 sec)
# INFO:tensorflow:global_step/sec: 299.469
# INFO:tensorflow:loss = 0.01673411, step = 25500 (0.336 sec)
# INFO:tensorflow:global_step/sec: 317.641
# INFO:tensorflow:loss = 0.029139206, step = 25600 (0.315 sec)
# INFO:tensorflow:global_step/sec: 311.694
# INFO:tensorflow:loss = 0.017962098, step = 25700 (0.321 sec)
# INFO:tensorflow:global_step/sec: 298.571
# INFO:tensorflow:loss = 0.045886584, step = 25800 (0.335 sec)
# INFO:tensorflow:global_step/sec: 313.805
# INFO:tensorflow:loss = 0.002598794, step = 25900 (0.316 sec)
# INFO:tensorflow:global_step/sec: 304.444
# INFO:tensorflow:loss = 0.013752665, step = 26000 (0.329 sec)
# INFO:tensorflow:global_step/sec: 308.896
# INFO:tensorflow:loss = 0.025175223, step = 26100 (0.325 sec)
# INFO:tensorflow:global_step/sec: 277.247
# INFO:tensorflow:loss = 0.035373278, step = 26200 (0.359 sec)
# INFO:tensorflow:global_step/sec: 300.32
# INFO:tensorflow:loss = 0.042373598, step = 26300 (0.335 sec)
# INFO:tensorflow:global_step/sec: 300.064
# INFO:tensorflow:loss = 0.010636547, step = 26400 (0.334 sec)
# INFO:tensorflow:global_step/sec: 271.615
# INFO:tensorflow:loss = 0.038245786, step = 26500 (0.368 sec)
# INFO:tensorflow:global_step/sec: 313.477
# INFO:tensorflow:loss = 0.01922036, step = 26600 (0.318 sec)
# INFO:tensorflow:global_step/sec: 302.256
# INFO:tensorflow:loss = 0.08622011, step = 26700 (0.333 sec)
# INFO:tensorflow:global_step/sec: 294.954
# INFO:tensorflow:loss = 0.034860022, step = 26800 (0.338 sec)
# INFO:tensorflow:global_step/sec: 320.863
# INFO:tensorflow:loss = 0.04839846, step = 26900 (0.310 sec)
# INFO:tensorflow:global_step/sec: 305.076
# INFO:tensorflow:loss = 0.03751236, step = 27000 (0.329 sec)
# INFO:tensorflow:global_step/sec: 292.205
# INFO:tensorflow:loss = 0.16994816, step = 27100 (0.341 sec)
# INFO:tensorflow:global_step/sec: 311.513
# INFO:tensorflow:loss = 0.009579392, step = 27200 (0.321 sec)
# INFO:tensorflow:global_step/sec: 327.675
# INFO:tensorflow:loss = 0.029082768, step = 27300 (0.305 sec)
# INFO:tensorflow:global_step/sec: 301.133
# INFO:tensorflow:loss = 0.038646188, step = 27400 (0.333 sec)
# INFO:tensorflow:global_step/sec: 292.75
# INFO:tensorflow:loss = 0.033710033, step = 27500 (0.341 sec)
# INFO:tensorflow:global_step/sec: 315.03
# INFO:tensorflow:loss = 0.073120475, step = 27600 (0.320 sec)
# INFO:tensorflow:global_step/sec: 299.983
# INFO:tensorflow:loss = 0.025506333, step = 27700 (0.331 sec)
# INFO:tensorflow:global_step/sec: 318.167
# INFO:tensorflow:loss = 0.0002615332, step = 27800 (0.314 sec)
# INFO:tensorflow:global_step/sec: 317.439
# INFO:tensorflow:loss = 0.00742818, step = 27900 (0.315 sec)
# INFO:tensorflow:global_step/sec: 303.928
# INFO:tensorflow:loss = 0.009099488, step = 28000 (0.329 sec)
# INFO:tensorflow:global_step/sec: 315.598
# INFO:tensorflow:loss = 0.07006903, step = 28100 (0.317 sec)
# INFO:tensorflow:global_step/sec: 325.262
# INFO:tensorflow:loss = 0.042871356, step = 28200 (0.308 sec)
# INFO:tensorflow:global_step/sec: 311.134
# INFO:tensorflow:loss = 0.026024176, step = 28300 (0.321 sec)
# INFO:tensorflow:global_step/sec: 293.878
# INFO:tensorflow:loss = 0.0064343773, step = 28400 (0.340 sec)
# INFO:tensorflow:global_step/sec: 314.813
# INFO:tensorflow:loss = 0.03332324, step = 28500 (0.317 sec)
# INFO:tensorflow:global_step/sec: 312.723
# INFO:tensorflow:loss = 0.008263051, step = 28600 (0.320 sec)
# INFO:tensorflow:global_step/sec: 281.955
# INFO:tensorflow:loss = 0.003463583, step = 28700 (0.356 sec)
# INFO:tensorflow:global_step/sec: 307.26
# INFO:tensorflow:loss = 0.0038512058, step = 28800 (0.325 sec)
# INFO:tensorflow:global_step/sec: 279.164
# INFO:tensorflow:loss = 0.007871685, step = 28900 (0.361 sec)
# INFO:tensorflow:global_step/sec: 297.217
# INFO:tensorflow:loss = 0.032324888, step = 29000 (0.335 sec)
# INFO:tensorflow:global_step/sec: 301.671
# INFO:tensorflow:loss = 0.012275027, step = 29100 (0.332 sec)
# INFO:tensorflow:global_step/sec: 311.547
# INFO:tensorflow:loss = 0.1044794, step = 29200 (0.319 sec)
# INFO:tensorflow:global_step/sec: 292.293
# INFO:tensorflow:loss = 0.037479807, step = 29300 (0.345 sec)
# INFO:tensorflow:global_step/sec: 278.385
# INFO:tensorflow:loss = 0.036247645, step = 29400 (0.356 sec)
# INFO:tensorflow:global_step/sec: 313.583
# INFO:tensorflow:loss = 0.014262387, step = 29500 (0.321 sec)
# INFO:tensorflow:global_step/sec: 309.981
# INFO:tensorflow:loss = 0.097094335, step = 29600 (0.321 sec)
# INFO:tensorflow:global_step/sec: 310.553
# INFO:tensorflow:loss = 0.0346921, step = 29700 (0.321 sec)
# INFO:tensorflow:global_step/sec: 319.111
# INFO:tensorflow:loss = 0.010621559, step = 29800 (0.314 sec)
# INFO:tensorflow:global_step/sec: 301.618
# INFO:tensorflow:loss = 0.054052155, step = 29900 (0.332 sec)
# INFO:tensorflow:global_step/sec: 305.058
# INFO:tensorflow:loss = 0.042936087, step = 30000 (0.330 sec)
# INFO:tensorflow:global_step/sec: 307.498
# INFO:tensorflow:loss = 0.0036757027, step = 30100 (0.323 sec)
# INFO:tensorflow:global_step/sec: 315.834
# INFO:tensorflow:loss = 0.024418756, step = 30200 (0.318 sec)
# INFO:tensorflow:global_step/sec: 309.8
# INFO:tensorflow:loss = 0.028145315, step = 30300 (0.322 sec)
# INFO:tensorflow:global_step/sec: 311.234
# INFO:tensorflow:loss = 0.11840231, step = 30400 (0.321 sec)
# INFO:tensorflow:global_step/sec: 307.221
# INFO:tensorflow:loss = 0.06743259, step = 30500 (0.326 sec)
# INFO:tensorflow:global_step/sec: 309.954
# INFO:tensorflow:loss = 0.057495248, step = 30600 (0.324 sec)
# INFO:tensorflow:global_step/sec: 301.829
# INFO:tensorflow:loss = 0.064721495, step = 30700 (0.332 sec)
# INFO:tensorflow:global_step/sec: 315.622
# INFO:tensorflow:loss = 0.023038285, step = 30800 (0.315 sec)
# INFO:tensorflow:global_step/sec: 315.088
# INFO:tensorflow:loss = 0.07987252, step = 30900 (0.317 sec)
# INFO:tensorflow:global_step/sec: 294.058
# INFO:tensorflow:loss = 0.02394388, step = 31000 (0.340 sec)
# INFO:tensorflow:global_step/sec: 312.206
# INFO:tensorflow:loss = 0.026111001, step = 31100 (0.323 sec)
# INFO:tensorflow:global_step/sec: 312.344
# INFO:tensorflow:loss = 0.0016998948, step = 31200 (0.319 sec)
# INFO:tensorflow:global_step/sec: 300.738
# INFO:tensorflow:loss = 0.0097646015, step = 31300 (0.331 sec)
# INFO:tensorflow:global_step/sec: 315.439
# INFO:tensorflow:loss = 0.004475843, step = 31400 (0.317 sec)
# INFO:tensorflow:global_step/sec: 312.009
# INFO:tensorflow:loss = 0.18652153, step = 31500 (0.320 sec)
# INFO:tensorflow:global_step/sec: 310.391
# INFO:tensorflow:loss = 0.040421285, step = 31600 (0.324 sec)
# INFO:tensorflow:global_step/sec: 304.538
# INFO:tensorflow:loss = 0.033100676, step = 31700 (0.328 sec)
# INFO:tensorflow:global_step/sec: 282.707
# INFO:tensorflow:loss = 0.029514845, step = 31800 (0.353 sec)
# INFO:tensorflow:global_step/sec: 314.105
# INFO:tensorflow:loss = 0.052821685, step = 31900 (0.318 sec)
# INFO:tensorflow:global_step/sec: 312.37
# INFO:tensorflow:loss = 0.008312257, step = 32000 (0.320 sec)
# INFO:tensorflow:global_step/sec: 312.003
# INFO:tensorflow:loss = 0.014622151, step = 32100 (0.321 sec)
# INFO:tensorflow:global_step/sec: 316.944
# INFO:tensorflow:loss = 0.0134436255, step = 32200 (0.315 sec)
# INFO:tensorflow:global_step/sec: 320.857
# INFO:tensorflow:loss = 0.004640534, step = 32300 (0.313 sec)
# INFO:tensorflow:global_step/sec: 282.546
# INFO:tensorflow:loss = 0.012614617, step = 32400 (0.353 sec)
# INFO:tensorflow:global_step/sec: 300.416
# INFO:tensorflow:loss = 0.0104681, step = 32500 (0.336 sec)
# INFO:tensorflow:global_step/sec: 282.187
# INFO:tensorflow:loss = 0.024479311, step = 32600 (0.353 sec)
# INFO:tensorflow:global_step/sec: 314.281
# INFO:tensorflow:loss = 0.055843394, step = 32700 (0.319 sec)
# INFO:tensorflow:global_step/sec: 312.473
# INFO:tensorflow:loss = 0.0012072504, step = 32800 (0.318 sec)
# INFO:tensorflow:global_step/sec: 299.492
# INFO:tensorflow:loss = 0.014209264, step = 32900 (0.335 sec)
# INFO:tensorflow:global_step/sec: 274.271
# INFO:tensorflow:loss = 0.018602213, step = 33000 (0.364 sec)
# INFO:tensorflow:global_step/sec: 307.571
# INFO:tensorflow:loss = 0.017626079, step = 33100 (0.325 sec)
# INFO:tensorflow:global_step/sec: 292.403
# INFO:tensorflow:loss = 0.00068202306, step = 33200 (0.341 sec)
# INFO:tensorflow:global_step/sec: 266.482
# INFO:tensorflow:loss = 0.028458722, step = 33300 (0.377 sec)
# INFO:tensorflow:global_step/sec: 232.071
# INFO:tensorflow:loss = 0.031027269, step = 33400 (0.430 sec)
# INFO:tensorflow:global_step/sec: 302.252
# INFO:tensorflow:loss = 0.0041906387, step = 33500 (0.332 sec)
# INFO:tensorflow:global_step/sec: 284.98
# INFO:tensorflow:loss = 0.02866217, step = 33600 (0.349 sec)
# INFO:tensorflow:global_step/sec: 307.771
# INFO:tensorflow:loss = 0.023419393, step = 33700 (0.326 sec)
# INFO:tensorflow:global_step/sec: 290.022
# INFO:tensorflow:loss = 0.030911483, step = 33800 (0.344 sec)
# INFO:tensorflow:global_step/sec: 296.826
# INFO:tensorflow:loss = 0.01760477, step = 33900 (0.337 sec)
# INFO:tensorflow:global_step/sec: 307.38
# INFO:tensorflow:loss = 0.02832165, step = 34000 (0.328 sec)
# INFO:tensorflow:global_step/sec: 297.313
# INFO:tensorflow:loss = 0.0059842775, step = 34100 (0.333 sec)
# INFO:tensorflow:global_step/sec: 289.674
# INFO:tensorflow:loss = 0.016547337, step = 34200 (0.346 sec)
# INFO:tensorflow:global_step/sec: 316.624
# INFO:tensorflow:loss = 0.027063183, step = 34300 (0.316 sec)
# INFO:tensorflow:global_step/sec: 302.321
# INFO:tensorflow:loss = 0.08147816, step = 34400 (0.330 sec)
# INFO:tensorflow:global_step/sec: 297.89
# INFO:tensorflow:loss = 0.032537572, step = 34500 (0.337 sec)
# INFO:tensorflow:global_step/sec: 307.398
# INFO:tensorflow:loss = 0.0025949895, step = 34600 (0.325 sec)
# INFO:tensorflow:global_step/sec: 309.199
# INFO:tensorflow:loss = 0.0037365716, step = 34700 (0.323 sec)
# INFO:tensorflow:global_step/sec: 282.729
# INFO:tensorflow:loss = 0.019779958, step = 34800 (0.356 sec)
# INFO:tensorflow:global_step/sec: 223.652
# INFO:tensorflow:loss = 0.00042173872, step = 34900 (0.448 sec)
# INFO:tensorflow:global_step/sec: 260.177
# INFO:tensorflow:loss = 0.08679136, step = 35000 (0.385 sec)
# INFO:tensorflow:global_step/sec: 294.592
# INFO:tensorflow:loss = 0.048261233, step = 35100 (0.336 sec)
# INFO:tensorflow:global_step/sec: 314.842
# INFO:tensorflow:loss = 0.08397669, step = 35200 (0.320 sec)
# INFO:tensorflow:global_step/sec: 288.794
# INFO:tensorflow:loss = 0.002116794, step = 35300 (0.344 sec)
# INFO:tensorflow:global_step/sec: 300.203
# INFO:tensorflow:loss = 0.022885088, step = 35400 (0.333 sec)
# INFO:tensorflow:global_step/sec: 284.943
# INFO:tensorflow:loss = 0.02880577, step = 35500 (0.352 sec)
# INFO:tensorflow:global_step/sec: 313.087
# INFO:tensorflow:loss = 0.0019446474, step = 35600 (0.320 sec)
# INFO:tensorflow:global_step/sec: 290.881
# INFO:tensorflow:loss = 0.0096355025, step = 35700 (0.343 sec)
# INFO:tensorflow:global_step/sec: 302.022
# INFO:tensorflow:loss = 0.018617436, step = 35800 (0.334 sec)
# INFO:tensorflow:global_step/sec: 303.222
# INFO:tensorflow:loss = 0.008957931, step = 35900 (0.329 sec)
# INFO:tensorflow:global_step/sec: 289.914
# INFO:tensorflow:loss = 0.02874535, step = 36000 (0.343 sec)
# INFO:tensorflow:global_step/sec: 311.933
# INFO:tensorflow:loss = 0.031241413, step = 36100 (0.322 sec)
# INFO:tensorflow:global_step/sec: 319.063
# INFO:tensorflow:loss = 0.008327157, step = 36200 (0.312 sec)
# INFO:tensorflow:global_step/sec: 304.535
# INFO:tensorflow:loss = 0.0048054736, step = 36300 (0.328 sec)
# INFO:tensorflow:global_step/sec: 243.42
# INFO:tensorflow:loss = 0.01613349, step = 36400 (0.411 sec)
# INFO:tensorflow:global_step/sec: 257.276
# INFO:tensorflow:loss = 0.023798991, step = 36500 (0.389 sec)
# INFO:tensorflow:global_step/sec: 313.778
# INFO:tensorflow:loss = 0.033107933, step = 36600 (0.318 sec)
# INFO:tensorflow:global_step/sec: 312.098
# INFO:tensorflow:loss = 0.00736191, step = 36700 (0.321 sec)
# INFO:tensorflow:global_step/sec: 307.203
# INFO:tensorflow:loss = 0.031177716, step = 36800 (0.325 sec)
# INFO:tensorflow:global_step/sec: 309.332
# INFO:tensorflow:loss = 0.013773834, step = 36900 (0.324 sec)
# INFO:tensorflow:global_step/sec: 293.701
# INFO:tensorflow:loss = 0.014208365, step = 37000 (0.340 sec)
# INFO:tensorflow:global_step/sec: 311.249
# INFO:tensorflow:loss = 0.008930125, step = 37100 (0.323 sec)
# INFO:tensorflow:global_step/sec: 289.348
# INFO:tensorflow:loss = 0.012830379, step = 37200 (0.344 sec)
# INFO:tensorflow:global_step/sec: 304.718
# INFO:tensorflow:loss = 0.0041731372, step = 37300 (0.328 sec)
# INFO:tensorflow:global_step/sec: 309.413
# INFO:tensorflow:loss = 0.010006526, step = 37400 (0.325 sec)
# INFO:tensorflow:global_step/sec: 295.214
# INFO:tensorflow:loss = 0.015905855, step = 37500 (0.340 sec)
# INFO:tensorflow:global_step/sec: 298.305
# INFO:tensorflow:loss = 0.014800444, step = 37600 (0.335 sec)
# INFO:tensorflow:global_step/sec: 295.947
# INFO:tensorflow:loss = 0.017969212, step = 37700 (0.337 sec)
# INFO:tensorflow:global_step/sec: 280.282
# INFO:tensorflow:loss = 0.03554515, step = 37800 (0.355 sec)
# INFO:tensorflow:global_step/sec: 288.462
# INFO:tensorflow:loss = 0.008504733, step = 37900 (0.347 sec)
# INFO:tensorflow:global_step/sec: 314.046
# INFO:tensorflow:loss = 0.01788513, step = 38000 (0.319 sec)
# INFO:tensorflow:global_step/sec: 290.721
# INFO:tensorflow:loss = 0.028398292, step = 38100 (0.346 sec)
# INFO:tensorflow:global_step/sec: 308.753
# INFO:tensorflow:loss = 0.02405062, step = 38200 (0.323 sec)
# INFO:tensorflow:global_step/sec: 323.697
# INFO:tensorflow:loss = 0.0448443, step = 38300 (0.309 sec)
# INFO:tensorflow:global_step/sec: 286.004
# INFO:tensorflow:loss = 0.030054782, step = 38400 (0.351 sec)
# INFO:tensorflow:global_step/sec: 307.438
# INFO:tensorflow:loss = 0.025391132, step = 38500 (0.323 sec)
# INFO:tensorflow:global_step/sec: 283.941
# INFO:tensorflow:loss = 0.0038849835, step = 38600 (0.355 sec)
# INFO:tensorflow:global_step/sec: 290.109
# INFO:tensorflow:loss = 0.008416684, step = 38700 (0.341 sec)
# INFO:tensorflow:global_step/sec: 280.036
# INFO:tensorflow:loss = 0.012867845, step = 38800 (0.359 sec)
# INFO:tensorflow:global_step/sec: 302.801
# INFO:tensorflow:loss = 0.002455846, step = 38900 (0.331 sec)
# INFO:tensorflow:global_step/sec: 294.178
# INFO:tensorflow:loss = 0.0068633063, step = 39000 (0.340 sec)
# INFO:tensorflow:global_step/sec: 304.63
# INFO:tensorflow:loss = 0.002052168, step = 39100 (0.326 sec)
# INFO:tensorflow:global_step/sec: 314.737
# INFO:tensorflow:loss = 0.012256324, step = 39200 (0.320 sec)
# INFO:tensorflow:global_step/sec: 298.044
# INFO:tensorflow:loss = 0.01016497, step = 39300 (0.336 sec)
# INFO:tensorflow:global_step/sec: 306.893
# INFO:tensorflow:loss = 0.003409436, step = 39400 (0.325 sec)
# INFO:tensorflow:global_step/sec: 315.426
# INFO:tensorflow:loss = 0.0025592945, step = 39500 (0.315 sec)
# INFO:tensorflow:global_step/sec: 292.931
# INFO:tensorflow:loss = 0.023168586, step = 39600 (0.342 sec)
# INFO:tensorflow:global_step/sec: 305.072
# INFO:tensorflow:loss = 0.0034930457, step = 39700 (0.328 sec)
# INFO:tensorflow:global_step/sec: 312.499
# INFO:tensorflow:loss = 0.0003723907, step = 39800 (0.320 sec)
# INFO:tensorflow:global_step/sec: 298.944
# INFO:tensorflow:loss = 0.002489285, step = 39900 (0.337 sec)
# INFO:tensorflow:global_step/sec: 292.911
# INFO:tensorflow:loss = 0.050516814, step = 40000 (0.339 sec)
# INFO:tensorflow:global_step/sec: 330.602
# INFO:tensorflow:loss = 0.00471781, step = 40100 (0.302 sec)
# INFO:tensorflow:global_step/sec: 298.805
# INFO:tensorflow:loss = 0.023562603, step = 40200 (0.336 sec)
# INFO:tensorflow:global_step/sec: 300.159
# INFO:tensorflow:loss = 0.0077065993, step = 40300 (0.333 sec)
# INFO:tensorflow:global_step/sec: 300.937
# INFO:tensorflow:loss = 0.02219782, step = 40400 (0.333 sec)
# INFO:tensorflow:global_step/sec: 285.787
# INFO:tensorflow:loss = 0.011300422, step = 40500 (0.349 sec)
# INFO:tensorflow:global_step/sec: 307.198
# INFO:tensorflow:loss = 0.015406494, step = 40600 (0.325 sec)
# INFO:tensorflow:global_step/sec: 289.605
# INFO:tensorflow:loss = 0.011585731, step = 40700 (0.346 sec)
# INFO:tensorflow:global_step/sec: 298.034
# INFO:tensorflow:loss = 0.0024443949, step = 40800 (0.334 sec)
# INFO:tensorflow:global_step/sec: 324.509
# INFO:tensorflow:loss = 0.0011785827, step = 40900 (0.309 sec)
# INFO:tensorflow:global_step/sec: 310.433
# INFO:tensorflow:loss = 0.028882205, step = 41000 (0.321 sec)
# INFO:tensorflow:global_step/sec: 302.434
# INFO:tensorflow:loss = 0.006874416, step = 41100 (0.330 sec)
# INFO:tensorflow:global_step/sec: 292.351
# INFO:tensorflow:loss = 0.024009958, step = 41200 (0.343 sec)
# INFO:tensorflow:global_step/sec: 304.68
# INFO:tensorflow:loss = 0.016507568, step = 41300 (0.328 sec)
# INFO:tensorflow:global_step/sec: 296.372
# INFO:tensorflow:loss = 0.030409371, step = 41400 (0.337 sec)
# INFO:tensorflow:global_step/sec: 302.323
# INFO:tensorflow:loss = 0.0140026, step = 41500 (0.332 sec)
# INFO:tensorflow:global_step/sec: 278.867
# INFO:tensorflow:loss = 0.015401451, step = 41600 (0.360 sec)
# INFO:tensorflow:global_step/sec: 315.259
# INFO:tensorflow:loss = 0.010052297, step = 41700 (0.317 sec)
# INFO:tensorflow:global_step/sec: 300.516
# INFO:tensorflow:loss = 0.014199306, step = 41800 (0.333 sec)
# INFO:tensorflow:global_step/sec: 290.607
# INFO:tensorflow:loss = 0.03151823, step = 41900 (0.344 sec)
# INFO:tensorflow:global_step/sec: 307.648
# INFO:tensorflow:loss = 0.025719414, step = 42000 (0.324 sec)
# INFO:tensorflow:global_step/sec: 271.263
# INFO:tensorflow:loss = 0.008852686, step = 42100 (0.370 sec)
# INFO:tensorflow:global_step/sec: 263.414
# INFO:tensorflow:loss = 0.014277729, step = 42200 (0.377 sec)
# INFO:tensorflow:global_step/sec: 301.055
# INFO:tensorflow:loss = 0.012160834, step = 42300 (0.334 sec)
# INFO:tensorflow:global_step/sec: 274.675
# INFO:tensorflow:loss = 0.024473319, step = 42400 (0.362 sec)
# INFO:tensorflow:global_step/sec: 294.515
# INFO:tensorflow:loss = 0.02543439, step = 42500 (0.339 sec)
# INFO:tensorflow:global_step/sec: 294.676
# INFO:tensorflow:loss = 0.015976679, step = 42600 (0.339 sec)
# INFO:tensorflow:global_step/sec: 284.29
# INFO:tensorflow:loss = 0.0073734387, step = 42700 (0.354 sec)
# INFO:tensorflow:global_step/sec: 306.446
# INFO:tensorflow:loss = 0.011924265, step = 42800 (0.326 sec)
# INFO:tensorflow:global_step/sec: 304.167
# INFO:tensorflow:loss = 0.018531267, step = 42900 (0.330 sec)
# INFO:tensorflow:global_step/sec: 277.976
# INFO:tensorflow:loss = 0.025748376, step = 43000 (0.359 sec)
# INFO:tensorflow:global_step/sec: 302.519
# INFO:tensorflow:loss = 0.020703662, step = 43100 (0.329 sec)
# INFO:tensorflow:global_step/sec: 298.282
# INFO:tensorflow:loss = 0.0025621052, step = 43200 (0.335 sec)
# INFO:tensorflow:global_step/sec: 276.705
# INFO:tensorflow:loss = 0.0011785039, step = 43300 (0.361 sec)
# INFO:tensorflow:global_step/sec: 306.135
# INFO:tensorflow:loss = 0.011532966, step = 43400 (0.326 sec)
# INFO:tensorflow:global_step/sec: 297.137
# INFO:tensorflow:loss = 0.013938819, step = 43500 (0.337 sec)
# INFO:tensorflow:global_step/sec: 286.315
# INFO:tensorflow:loss = 0.02174255, step = 43600 (0.352 sec)
# INFO:tensorflow:global_step/sec: 287.139
# INFO:tensorflow:loss = 0.019327182, step = 43700 (0.347 sec)
# INFO:tensorflow:global_step/sec: 305.585
# INFO:tensorflow:loss = 0.012008071, step = 43800 (0.326 sec)
# INFO:tensorflow:global_step/sec: 294.063
# INFO:tensorflow:loss = 0.026121177, step = 43900 (0.340 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into /tmp/tmpjzdgrbgs/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.015394805.

# %%
# Test input function
test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_test}, y=y_test, shuffle=False)

# Test
eval_results = dnn_clf.evaluate(input_fn=test_input_fn)
eval_results
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-02-05T15:25:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpjzdgrbgs/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-02-05-15:25:11
# INFO:tensorflow:Saving dict for global step 44000: accuracy = 0.9796, average_loss = 0.099778555, global_step = 44000, loss = 12.630198
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: /tmp/tmpjzdgrbgs/model.ckpt-44000
# {'accuracy': 0.9796,
#  'average_loss': 0.099778555,
#  'global_step': 44000,
#  'loss': 12.630198}

# %% [markdown]
# ## 10.3 텐서플로의 저수준 API로 심층 신경망 학습하기
#
# 네트워크의 구조를 더 상세히 제어하고 싶으면 턴서플로의 저수준 파이썬 API이용
#
# 아래의 예제는 위에서 MNIST 분류기를 `Estimator`로 구현한 것을 이번에는 텐서플로 Low-Level로 구현한 것이다.

# %%
import tensorflow as tf

# MNIST Dataset Load!
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# reshape : 28 x 28 -> 784
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

# split validation set
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %% [markdown]
# #### 10.3.1 구성 단계

# %%
################
# layer params #
################
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

inputs = tf.placeholder(tf.float32, shape=[None, n_inputs], name="inputs")
labels = tf.placeholder(tf.int32, shape=[None], name="outputs")

# %%
# 뉴런 층
def neuron_layer(inputs, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(inputs.get_shape()[1])
        # stddev : 표준편차 / 이 표준편차를 사용하면 알고리즘이 훨씬 빠르게 수렴
        stddev = 2 / np.sqrt(n_inputs)
        # init 초기화 / 크기 : (n_inputs, n_neurons)
        init = tf.truncated_normal([n_inputs, n_neurons], stddev=stddev)
        weights = tf.Variable(init, name="weights")
        bias = tf.Variable(tf.zeros([n_neurons]), name='bias')
        Z = tf.matmul(inputs, weights) + bias
        if activation:
            return activation(Z)
        else:
            return Z

# %%
# 신경망 모델 준비
with tf.name_scope('dnn'):
    # 첫번쨰 은닉층
    hidden1 = neuron_layer(inputs, n_hidden1, name='hidden1', 
                           activation=tf.nn.relu)
    # 두번째 은닉층
    hidden2 = neuron_layer(hidden1, n_hidden2, name='hidden2',
                           activation=tf.nn.relu)
    # 출력층
    logits = neuron_layer(hidden2, n_outputs, name='logits')

# %%
# 비용 함수 정의
with tf.name_scope('loss'):
    cross_entropy = tf.reduce_mean(
        # 크로스 엔트로피를 사용
        tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits))

# %%
################
# Hyper-params #
################
learning_rate = 0.01
n_epochs = 40
batch_size = 50

with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    train_op = optimizer.minimize(cross_entropy)

# 평가하는 방법
with tf.name_scope('eval'):
    correct = tf.nn.in_top_k(predictions=logits, targets=labels, k=1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
#### 10.3.2 실행 단계

# %%
# train
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(train_op, feed_dict={inputs: X_batch,
                                          labels: y_batch})
        
        acc_batch = accuracy.eval(feed_dict={inputs: X_batch, labels: y_batch})
        acc_valid = accuracy.eval(feed_dict={inputs: X_valid, labels: y_valid})
        print('epoch: {:03d}, bacth acc: {:.4f}, valid acc: {:.4f}'.format(epoch,
                                                                          acc_batch,
                                                                          acc_valid))
# Out:
# epoch: 000, bacth acc: 0.9000, valid acc: 0.9174
# epoch: 001, bacth acc: 0.9200, valid acc: 0.9320
# epoch: 002, bacth acc: 0.9400, valid acc: 0.9386
# epoch: 003, bacth acc: 0.9400, valid acc: 0.9482
# epoch: 004, bacth acc: 0.9800, valid acc: 0.9528
# epoch: 005, bacth acc: 0.9800, valid acc: 0.9556
# epoch: 006, bacth acc: 0.9800, valid acc: 0.9596
# epoch: 007, bacth acc: 0.9800, valid acc: 0.9620
# epoch: 008, bacth acc: 0.9600, valid acc: 0.9640
# epoch: 009, bacth acc: 1.0000, valid acc: 0.9656
# epoch: 010, bacth acc: 1.0000, valid acc: 0.9684
# epoch: 011, bacth acc: 0.9800, valid acc: 0.9662
# epoch: 012, bacth acc: 0.9800, valid acc: 0.9686
# epoch: 013, bacth acc: 1.0000, valid acc: 0.9690
# epoch: 014, bacth acc: 0.9400, valid acc: 0.9690
# epoch: 015, bacth acc: 1.0000, valid acc: 0.9706
# epoch: 016, bacth acc: 0.9600, valid acc: 0.9718
# epoch: 017, bacth acc: 0.9800, valid acc: 0.9732
# epoch: 018, bacth acc: 1.0000, valid acc: 0.9716
# epoch: 019, bacth acc: 1.0000, valid acc: 0.9724
# epoch: 020, bacth acc: 0.9800, valid acc: 0.9730
# epoch: 021, bacth acc: 1.0000, valid acc: 0.9740
# epoch: 022, bacth acc: 1.0000, valid acc: 0.9716
# epoch: 023, bacth acc: 0.9800, valid acc: 0.9746
# epoch: 024, bacth acc: 1.0000, valid acc: 0.9744
# epoch: 025, bacth acc: 1.0000, valid acc: 0.9748
# epoch: 026, bacth acc: 0.9800, valid acc: 0.9742
# epoch: 027, bacth acc: 0.9800, valid acc: 0.9752
# epoch: 028, bacth acc: 1.0000, valid acc: 0.9754
# epoch: 029, bacth acc: 0.9800, valid acc: 0.9750
# epoch: 030, bacth acc: 0.9800, valid acc: 0.9756
# epoch: 031, bacth acc: 1.0000, valid acc: 0.9766
# epoch: 032, bacth acc: 0.9800, valid acc: 0.9766
# epoch: 033, bacth acc: 1.0000, valid acc: 0.9778
# epoch: 034, bacth acc: 0.9800, valid acc: 0.9754
# epoch: 035, bacth acc: 1.0000, valid acc: 0.9770
# epoch: 036, bacth acc: 1.0000, valid acc: 0.9770
# epoch: 037, bacth acc: 1.0000, valid acc: 0.9772
# epoch: 038, bacth acc: 1.0000, valid acc: 0.9762
# epoch: 039, bacth acc: 0.9800, valid acc: 0.9774

# %% [markdown]
# ### `neuron_layer()` 대신 `tf.layers.dense()` 사용

# %%
import tensorflow as tf

# MNIST Dataset Load!
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# reshape : 28 x 28 -> 784
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

# split validation set
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
# reset graph
tf.reset_default_graph()

################
# layer params #
################
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

inputs = tf.placeholder(tf.float32, shape=[None, n_inputs], name="inputs")
labels = tf.placeholder(tf.int32, shape=[None], name="outputs")

# %%
# 변경된 부분
with tf.name_scope('dnn'):
    hidden1 = tf.layers.dense(inputs=inputs, units=n_hidden1,
                              activation=tf.nn.relu, name='hidden1',
                              kernel_initializer=tf.truncated_normal_initializer(stddev=0.1))
    hidden2 = tf.layers.dense(hidden1, n_hidden2,
                              activation=tf.nn.relu, name='hidden2',
                              kernel_initializer=tf.truncated_normal_initializer(stddev=0.1))
    logits = tf.layers.dense(hidden2, n_outputs, name='logits')

# %%
with tf.name_scope('loss'):
    cross_entropy = tf.reduce_mean(
        tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits))

# %%
################
# Hyper-params #
################
learning_rate = 0.01
n_epochs = 40
batch_size = 50

with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    train_op = optimizer.minimize(cross_entropy)

with tf.name_scope('eval'):
    correct = tf.nn.in_top_k(predictions=logits, targets=labels, k=1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
# train
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(train_op, feed_dict={inputs: X_batch,
                                          labels: y_batch})
        
        acc_batch = accuracy.eval(feed_dict={inputs: X_batch, labels: y_batch})
        acc_valid = accuracy.eval(feed_dict={inputs: X_valid, labels: y_valid})
        print('epoch: {:03d}, bacth acc: {:.4f}, valid acc: {:.4f}'.format(epoch,
                                                                          acc_batch,
                                                                          acc_valid))
# Out:
# epoch: 000, bacth acc: 0.9200, valid acc: 0.9074
# epoch: 001, bacth acc: 0.8800, valid acc: 0.9274
# epoch: 002, bacth acc: 0.9400, valid acc: 0.9384
# epoch: 003, bacth acc: 0.9200, valid acc: 0.9428
# epoch: 004, bacth acc: 0.8600, valid acc: 0.9492
# epoch: 005, bacth acc: 1.0000, valid acc: 0.9520
# epoch: 006, bacth acc: 0.9400, valid acc: 0.9552
# epoch: 007, bacth acc: 0.9800, valid acc: 0.9580
# epoch: 008, bacth acc: 0.9600, valid acc: 0.9602
# epoch: 009, bacth acc: 0.9800, valid acc: 0.9618
# epoch: 010, bacth acc: 0.9600, valid acc: 0.9638
# epoch: 011, bacth acc: 0.9800, valid acc: 0.9652
# epoch: 012, bacth acc: 0.9800, valid acc: 0.9678
# epoch: 013, bacth acc: 0.9600, valid acc: 0.9694
# epoch: 014, bacth acc: 0.9600, valid acc: 0.9708
# epoch: 015, bacth acc: 1.0000, valid acc: 0.9690
# epoch: 016, bacth acc: 0.9800, valid acc: 0.9714
# epoch: 017, bacth acc: 0.9800, valid acc: 0.9710
# epoch: 018, bacth acc: 1.0000, valid acc: 0.9726
# epoch: 019, bacth acc: 0.9800, valid acc: 0.9736
# epoch: 020, bacth acc: 0.9600, valid acc: 0.9726
# epoch: 021, bacth acc: 1.0000, valid acc: 0.9734
# epoch: 022, bacth acc: 0.9800, valid acc: 0.9736
# epoch: 023, bacth acc: 0.9800, valid acc: 0.9732
# epoch: 024, bacth acc: 1.0000, valid acc: 0.9732
# epoch: 025, bacth acc: 1.0000, valid acc: 0.9744
# epoch: 026, bacth acc: 1.0000, valid acc: 0.9746
# epoch: 027, bacth acc: 1.0000, valid acc: 0.9746
# epoch: 028, bacth acc: 1.0000, valid acc: 0.9746
# epoch: 029, bacth acc: 1.0000, valid acc: 0.9750
# epoch: 030, bacth acc: 1.0000, valid acc: 0.9760
# epoch: 031, bacth acc: 1.0000, valid acc: 0.9750
# epoch: 032, bacth acc: 1.0000, valid acc: 0.9748
# epoch: 033, bacth acc: 0.9800, valid acc: 0.9756
# epoch: 034, bacth acc: 1.0000, valid acc: 0.9760
# epoch: 035, bacth acc: 0.9600, valid acc: 0.9766
# epoch: 036, bacth acc: 1.0000, valid acc: 0.9756
# epoch: 037, bacth acc: 1.0000, valid acc: 0.9764
# epoch: 038, bacth acc: 0.9800, valid acc: 0.9764
# epoch: 039, bacth acc: 1.0000, valid acc: 0.9770

# %%
# !pip install tfgraphviz
# Out:
# Requirement already satisfied: tfgraphviz in /usr/local/lib/python3.6/dist-packages (0.0.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from tfgraphviz) (0.10.1)

# %%
import graphviz
import tfgraphviz as tfg

tf_graph = tfg.board(tf.get_default_graph())
tf_graph

# %% [markdown]
# ## 10.4 신경망 하이퍼파라미터 튜닝하기
#
# - 교차 검증을 활용한 그리드 탐색
#   - 조정할 하이퍼파라미터가 많고 대규모 데이터셋에 신경망을 훈련할 때 오랜 시간이 걸림
#   - 주어진 시간 안에 전체 공간 중 작은 부분만 탐색 가능
#   - 이럴 때 랜덤 탐색 이용
#   - 또는 좋은 하이퍼파라미터 조합을 빠르게 찾아주는 복잡한 알고리즘들을 구현한 오스카 도구 이용

# %% [markdown]
# ### 10.4.1 은닉층의 수
#
# - 많은 문제가 하나 또는 두 개의 은닉층만 기지고도 꽤 잘 작동한다.
# - 훈련 데이터가 아주 많이 필요하다.
#
#
# ### 10.4.2 은닉층의 뉴런 수
#
# ### 10.4.3 활성화 함수
# - 대부분의 경우 은닉층에 ReLU 활성화 함수를 사용
#   - 다른 활성화 함수보다 계싼이 조금 더 빠르고 입력값이 클 때 특정 값에 수렴하지 않는다.
# - 출력층에서는 소프트맥스 활성화 함수가 일반적으로 분류 작업의 좋은 선택(클래스가 상호 배타적일 경우)
# - 회귀 작업일 경우는 활성화 함수를 사용하지 않는다.

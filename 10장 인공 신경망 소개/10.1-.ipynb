# %%
# 구글 드라이버 이용
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# 파일 불러오기 예시
import pandas as pd

pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/test.csv').head(2)

# 이미지 불러오기 예시
# ![](https://drive.google.com/uc?export=view&id=1z6Q2D-cznuPfBSZwd1MhuRxoB-1Bzodq)
# <img src= "https://drive.google.com/uc?export=view&id=1D9FfbEL9ORMLEHMMKZcq0mEd5gCiLhnh" width="400">
# Out:
#    PassengerId  Pclass                              Name  ...    Fare  Cabin  Embarked
# 0          892       3                  Kelly, Mr. James  ...  7.8292    NaN         Q
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  ...  7.0000    NaN         S
#
# [2 rows x 11 columns]

# %% [markdown]
# ## 10.1 생물학적 뉴런에서 인공 뉴런까지
#
# **인공 신경망**(ANN, Aritificial Neural Networks)은 1943년 신경생리학자 Warren McCulloch과 수학자 Walter Pitts가 ['A Logical Calculus of Ideas Immanent In Nervous Activity'](https://pdfs.semanticscholar.org/5272/8a99829792c3272043842455f3a110e841b1.pdf) 처음 소개했으며, 명제 논리(propositional logic)를 사용해 동물 뇌의 생물학적 뉴런이 복잡한 계산을 위해 어떻게 상호작용하는지에 대해 간단한 계산 모델을 제시했다.
#
# 1960년대까지는 이렇게 등장한 인공 신경망을 통해 사람들은 지능을 가진 기계와 대화를 나눌 수 있을 것이라고 생각했다. 하지만 아래 그림(출처: [beamandrew's blog](https://beamandrew.github.io/deeplearning/2017/02/23/deep_learning_101_part1.html))처럼 사람들의 기대와는 달리 인공 신경망으로 `XOR`문제를 해결할 수 없게 되었고, 1990년 대에는 SVM과 성능이 좋은 다른 머신러닝 알고리즘들이 나오게 되면서 인공 신경망은 암흑기로 접어 들게 되었다.
#
#
# 2000년 대에 들어서면서 인공 신경망은 2012년 ILSVRC2012 대회에서 인공 신경망을 깊게 쌓은 딥러닝 모델인 AlexNet이 압도적인 성적으로 우승하면서 다시금 주목받게 되었다. 이렇게 인공 신경망(딥러닝)이 다시 주목받게 된 계기는 다음과 같은 것들이 있다.
#
# - 빅 데이터 시대인 요즘 신경망을 학습시키기 위한 데이터가 엄청나게 많아 졌다.
# - 신경망은 다른 머신러닝 알고리즘보다 규모가 크고 복잡한 문제에서 성능이 좋다.
# - 1990년대 이후 크게 발전된 컴퓨터 하드웨어 성능과 Matrix연산에 고성능인 GPU로 인해 상대적으로 짧은 시간 안에 대규모의 신경망을 학습시킬 수 있게 되었다.

# %% [markdown]
# ### 10.1.1 생물학적 뉴런
#
# - 생물학적 뉴런
#   - 사람의 뇌에서 볼 수 있는 세포로써 핵(nucleus)을 포함하는 **세포체**(cell body)와 구성 요소로 이루어져 있다.
#   - **Dendrite** : 수상돌기, 다른 뉴런으로부터 신호를 수용하는 부분
#   - **Axon** : 축삭돌기, 신호를 내보내는 부분
#   - **Synaptic terminals** : 시냅스(synapse) 뉴런의 접합부, 다른 뉴런으로 부터 짧은 전기 자극 **신호**(signal)를 받음
#
# ![](https://drive.google.com/uc?export=view&id=1sW5uUEB0UaJKlbPqEuzDxDlnfWDAH_yZ)
#
# - 출처 : [wikipedia](https://en.wikipedia.org/wiki/Neuron)

# %% [markdown]
# ### 10.1.2 뉴런을 사용한 논리 연산
#
# 워런 맥컬록과 윌터 피츠는 매우 단순한 생물학적 뉴런 모델을 제안했는데, 나중에 이것이 **인공 뉴런**이 되었다.
#
# 처음 인공 신경망을 제안한  Warren McCulloch과 Walter Pitts의 인공 뉴런 모델은 아래의 그림(출처: 핸즈온-머신러닝)과 같다.
#
# 이 모델은 하나 이상의 이진(`on/off`) 입력과 하나의 출력을 가진다.
#
# ![](https://drive.google.com/uc?export=view&id=1p9XTUj6qeUJA1LIua2XlC1FsnggX_rnj)
#
#
#
# - ①은 항등함수를 의미하며, 뉴런 `A`가 활성화 되면 뉴런 `C` 또한 활성화된다.
# - ②는 논리곱 연산을 의미하며, 뉴런 `A`와 `B`가 모두 활성화될 때만 뉴런 `C`가 활성화된다.
# - ③은 논리합 연산을 의미하며, 뉴런 `A`와 `B` 둘 중 하나라도 활성화되면 `C`가 활성화된다.
# - ④는 어떤 입력이 뉴런의 활성화를 억제할 수 있다고 가정하면, 위의 그림에서 처럼 뉴런 `A`가 활성화 되고 `B`가 비활성화될 때 뉴런 `C`가 활성화된다.

# %% [markdown]
# ### 10.1.3 퍼셉트론
#
# **퍼셉트론**(Perceptron)은 Frank Rosenblatt가 1975년에 제안한 인공 신경망 구조 중 하나이며, 이 퍼셉트론이 바로 신경망(딥러닝)의 기원이 되는 알고리즘이라고 할 수 있다.
#
# 퍼셉트론은 **TLU**(Threshold Logic Unit)이라는 형태의 뉴런을 기반으로 하며, 아래의 그림과 같이 입력과 출력이 어떤 숫자고 각각의 입력에 각각 고유한 **가중치**($\mathbf{W}$, weight)가 곱해진다.
#
# $$
# z = w_1x_1 + w_2x_2 + \cdots + w_nx_n = \mathbf{W}^{T} \cdot \mathbf{X}
# $$
#
# 그런 다음 계산된 합 $z$에 **계단 함수**(step function)를 적용하여 결과 $h$를 출력한다.
#
# $$
# \begin{align*}
# h_w(\mathbf{X}) &= \text{step}(z) \\ &= \text{step}(\mathbf{W}^{T} \cdot \mathbf{X})
# \end{align*}
# $$
#
# <img src= "https://drive.google.com/uc?export=view&id=1D9FfbEL9ORMLEHMMKZcq0mEd5gCiLhnh" width="400">

# %% [markdown]
# **헤비사이드 계단 함수**
#   - 퍼셉트론에서 가장 널리 사용되는 계단 함수
#   - 계단 함수 대신 부호 함수(sign function)을 사용하기도 한다.
# $$
# \text{heaviside}(z)=\begin{cases} 0 \text{  (}z < 0)  \\ 1 \text{  (}z \ge 0) \end{cases}, \quad \text{sgn}(z)= \begin{cases} -1 \text{  (}z < 0)\\ 0 \text{ (}z = 0)\\ +1 \text{  (}z > 0)\end{cases}
# $$
#
# 위의 그림에서 처럼, 하나의 TLU는 입력과 가중치의 선형결합인 $z$가 $z \ge 0$ 이면 양성 클래스, $z < 0$이면 음성 클래스를 출력하게 하는 **선형 이진 분류**(linear binary classification)에 적용할 수 있다.
#
# 아래의 그림은 위의 TLU를 세 개로 구성한 퍼셉트론에 편향($x_0=1$)을 추가한 것이다. 이 퍼셉트론은 샘플 세 개의 클래스(레이블)로 분류할 수 있는 **다중 출력 분류기**(Multioutput Classifier)이다.
#
# <img src = "https://drive.google.com/uc?export=view&id=1wQbwSU6X320GcL2hGGjrzE0u9x0fSWH0" width = "400">

# %% [markdown]
# **헤브 학습**
#   - 서로 활성화되는 세포가 서로 연결된다.
#   - 두 뉴런이 동일한 출력을 낼 때마다 이 둘 사이의 연결 가중치가 증가
#
#
# **퍼셉트론 학습 규칙(가중치 업데이트)**
#
# $$
# w_{i,j}^{\text{(next step)}} = w_{i,j} + \eta \left( y_j - \hat{y}_j \right) x_i
# $$
#
# - $w_{i,j}$ : $i$-번째 입력 뉴런과 $j$-번째 출력 뉴런 사이를 연결하는 가중치
# - $x_i$ : 현재 학습 데이터 샘플의 $i$-번째 뉴런의 입력값
# - $\hat{y}_j$ : 현재 학습 데이터 샘플의 $j$-번째 출력 뉴런의 출력값
# - $y_j$ : 현재 학습 데이터 샘플의 $j$-번째 출력 뉴런의 실제값
#
# **퍼셉트론 수렴 이론**(Perceptron convergence theorem)
#   - Frank Rosenblatt는 학습 데이터가 선형적으로 구분될 수 있으면, 퍼셉트론은 정답에 수렴한다는 것

# %% [markdown]
# #### Scikit-Learn의 Perceptron 클래스
#
# Scikit-Learn은 하나의 TLU 퍼셉트론을 구현한 `Perceptron`클래스를 제공한다.
# 아래의 예제는 iris dataset(붓꽃 데이터셋)에서 꽃잎의 길이(`petal length`)와 너비(`petal width`)를 가지고 붓꽃 종류 중 `Setosa`인지 아닌지를 분류하는 이진 분류기를 구현한 것이다.

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron
import numpy as np

iris = load_iris()
# 꽃잎의 길이와 너비
X = iris.data[:, (2, 3)]
# Iris sentosa 인지
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(max_iter=100, random_state=42)
per_clf.fit(X, y)

# 1이면 iris sentosa
# 0이면 iris sentosa가 아니다
y_pred = per_clf.predict([[2, 0.5]])
print(y_pred)
# Out:
# [1]

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')
# %matplotlib inline

a = -per_clf.coef_[0][0] / per_clf.coef_[0][1]
b = -per_clf.intercept_ / per_clf.coef_[0][1]

axes = [0, 5, 0, 2]

x0, x1 = np.meshgrid(
        np.linspace(axes[0], axes[1], 500).reshape(-1, 1),
        np.linspace(axes[2], axes[3], 200).reshape(-1, 1),
    )
X_new = np.c_[x0.ravel(), x1.ravel()]
y_predict = per_clf.predict(X_new)
zz = y_predict.reshape(x0.shape)

plt.figure(figsize=(10, 4))
plt.plot(X[y==0, 0], X[y==0, 1], "bs", label="Iris-Setosa 아님")
plt.plot(X[y==1, 0], X[y==1, 1], "yo", label="Iris-Setosa")

plt.plot([axes[0], axes[1]], [a * axes[0] + b, a * axes[1] + b], "k-", linewidth=3)
from matplotlib.colors import ListedColormap
custom_cmap = ListedColormap(['#9898ff', '#fafab0'])

plt.contourf(x0, x1, zz, cmap=custom_cmap)
plt.xlabel("꽃잎 길이", fontsize=14)
plt.ylabel("꽃잎 너비", fontsize=14)
plt.legend(loc="lower right", fontsize=14)
plt.axis(axes)
plt.show()

# %% [markdown]
# #### 퍼셉트론의 약점: XOR 문제
#
# 1969년 Marvin Minsky와 Seymour Papert는 '퍼셉트론'이란 논문에서 퍼셉트론의 심각한 약점이 있다는 것을 보였는데, 그 중에서도 가장 결정적인 것은 선형결합인 퍼셉트론이 배타적 논리합인 XOR 분류 문제를 해결할 수 없다는 것이었다.
#
#
# 이를 계기로 인공 신경망은 암흑기를 맞이하게 되었다. 하지만, 단일 퍼셉트론을 여러개 쌓아 **다층 퍼셉트론**(**MLP**, Multi-Layer Perceptron)을 통해 XOR 분류 문제를 해결할 수 있었다.
#
# <img src = "https://drive.google.com/uc?export=view&id=1TPmHrgEaTzwK4yQokoMQGVDW_CKZf-b0">

# %% [markdown]
# ### 10.1.4 다층 퍼셉트론과 역전파
#
# 다층 퍼셉트론(MLP)은 **입력층**, **은닉층(hidden layer)**이라 부르는 하나 이상의 TLU 층과 마지막으로 **출력층**(output layer)으로 구성된다.
# 인공 신경망의 은닉층이 2개 이상일 때, **심층 신경망**(**DNN**, Deep Neural Network)라 하고 이를 학습하여 모델을 만드는 것을 **딥러닝**(Deep-Learning) 이라고 한다.
#
# 이렇게 여러층을 쌓은 MLP를 통해 XOR 문제를 해결 했지만, 층이 깊어질 수록 증가하는 가중치 매개변수의 수로 인해 다층 퍼셉트론을 학습시키기에는 오랜 시간이 걸리는 문제가 발생했다. 하지만, 1986년 **역전파(backpropogation)** 알고리즘이 등장하면서 계산량을 획기적으로 줄일 수 있게 되었다.
#
#
# - 역전파법
#   1. **순전파** : 각 학습 데이터 샘플을 네트워크에 입력으로 넣어주고 출력층까지 각 층의 뉴런 마다 출력을 계산
#   2. 마지막 출력층에 대한 결과(예측값)와 실제값과의 차이, 즉 오차(error)를 계산하는데, 손실함수(loss function)를 이용해 계산
#   3. 오차를 역방향으로 흘러 보내면서, 각 출력 뉴런의 오차에 마지막 입력 뉴런이 얼마나 기여했는지 측정
#     - **각 뉴런의 입력값에 대한 손실함수의 편미분, 그래디언트(gradient)을 계산**하는 것을 말한다.
#   4. 3번과 같은 방법을 입력층에 도달할 때까지 계속 반복해서 역방향으로 흘러 보낸다.
#   5. 마지막으로, 계산한 그래디언트를 네트워크의 모든 가중치 매개변수에 반영해주는 **경사 하강법 단계**를 수행
#
# 따라서, 먼저 순전파를 통해 네트워크가 예측을 출력(출력층의 출력 결과)하고, 이를 손실함수를 이용해 오차를 계산한 뒤, 역방향으로 거슬러 올라가면서 각 뉴런의 입력값에 대한 손실함수의 편미분을 계산하고(backpropagation), 이를 경사 하강법을 이용해 가중치를 조정하는 방법이 역전파 알고리즘이다.

# %% [markdown]
# #### 활성화 함수 (activation function)
#
# 역전파 알고리즘이 잘 동작하기 위해서 다층 퍼셉트론(MLP)의 구조에 변화를 주었는 데, 그것이 바로 활성화 함수 부분에서 계단 함수를 시그모이드 함수(로지스틱 함수)로 바꿔준 것이다.
#
# 이렇게 활성화 함수를 시그모이드 함수로 바꿔준 이유는 가중치 매개변수를 조정 해주기 위해 그래디언트, 편미분을 계산하게 되는데, 계단 함수는 0을 기준으로 기울기가 없는 직선이므로 그래디언트를 계산하는 것이 의미가 없기 때문이다
#
# 활성화 함수로는 아래의 그림처럼 로지스틱 함수 외에 다양한 활성화 함수를 사용할 수 있다.

# %%
def logit(z):
    return 1 / (1 + np.exp(-z))

def relu(z):
    return np.maximum(0, z)

def derivative(f, z, eps=0.000001):
    return (f(z + eps) - f(z - eps))/(2 * eps)

# %%
z = np.linspace(-5, 5, 200)

plt.figure(figsize=(11,4))

plt.subplot(121)
plt.plot(z, np.sign(z), "r-", linewidth=2, label="스텝")
plt.plot(z, logit(z), "g--", linewidth=2, label="로지스틱")
plt.plot(z, np.tanh(z), "b-", linewidth=2, label="Tanh")
plt.plot(z, relu(z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
plt.legend(loc="center right", fontsize=14)
plt.title("활성화 함수", fontsize=14)
plt.axis([-5, 5, -1.2, 1.2])

plt.subplot(122)
plt.plot(z, derivative(np.sign, z), "r-", linewidth=2, label="Step")
plt.plot(0, 0, "ro", markersize=5)
plt.plot(0, 0, "rx", markersize=10)
plt.plot(z, derivative(logit, z), "g--", linewidth=2, label="Logit")
plt.plot(z, derivative(np.tanh, z), "b-", linewidth=2, label="Tanh")
plt.plot(z, derivative(relu, z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
plt.title("도함수", fontsize=14)
plt.axis([-5, 5, -0.2, 1.2])
plt.show()

# %% [markdown]
# #### 소프트맥스(softmax) 함수
#
# **소프트맥스 함수**(softmax function)는 출력층에서 주로 사용하는 활성화 함수이며, 식은 다음과 같다.
# $$
# \hat{y}_k = \frac{ \text{exp} \left( \mathbf{W}^{T} \cdot \mathbf{x} \right)}{\sum_{j=1}^{K}{\text{exp} \left( \mathbf{W}^{T} \cdot \mathbf{x} \right)}} \quad (K=\text{# of class})
# $$
#
#
# 소프트맥스 함수의 특징은 출력값의 총합이 1이 된다는 것이다. 따라서, 각 출력 뉴런에 대한 소프트맥스의 출력값은 각 클래스에 대응하는 추정 확률값으로 볼 수 있다.

# %% [markdown]
# ## 10.2 텐서플로 고수준 API로 다층 퍼셉트론 학습하기
#
# 텐서플로는 사용자가 쉽게 신경망 모델링을 프로그래밍할 수 있도록 high-level의 API를 제공한다. 대표적인 high-level API로는 `tf.estimator`와 `keras`가 있는데, 이에 대한 자세한 내용은 [여기](http://excelsior-cjh.tistory.com/157?category=940399)에서 참고하면 된다.
#
# 아래의 예제는 `tf.estimator`의 `DNNClassifier` 클래스를 이용해 MNIST 숫자 데이터를 분류하는 DNN을 구현한 것이다.

# %%
# MNIST Dataset Load!
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# reshape : 28 x 28 -> 784
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

# split validation set
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
# TF Estimator
feature_cols = [tf.feature_column.numeric_column("X", shape=[28 * 28])]
dnn_clf = tf.estimator.DNNClassifier(hidden_units=[300, 100], n_classes=10,
                                     feature_columns=feature_cols)

# input function
input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_train}, y=y_train, num_epochs=40, batch_size=50, shuffle=True)

# training
dnn_clf.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\jongm\AppData\Local\Temp\tmp16z4p7tg
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\jongm\\AppData\\Local\\Temp\\tmp16z4p7tg', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000023442A067F0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\jongm\AppData\Local\Temp\tmp16z4p7tg\model.ckpt.
# INFO:tensorflow:loss = 118.47757, step = 1
# INFO:tensorflow:global_step/sec: 300.577
# INFO:tensorflow:loss = 18.2126, step = 101 (0.333 sec)
# INFO:tensorflow:global_step/sec: 320.597
# INFO:tensorflow:loss = 9.526357, step = 201 (0.312 sec)
# INFO:tensorflow:global_step/sec: 349.977
# INFO:tensorflow:loss = 8.640748, step = 301 (0.301 sec)
# INFO:tensorflow:global_step/sec: 292.157
# INFO:tensorflow:loss = 4.5524364, step = 401 (0.330 sec)
# INFO:tensorflow:global_step/sec: 302.333
# INFO:tensorflow:loss = 8.764444, step = 501 (0.331 sec)
# INFO:tensorflow:global_step/sec: 337.307
# INFO:tensorflow:loss = 9.664594, step = 601 (0.293 sec)
# INFO:tensorflow:global_step/sec: 316.077
# INFO:tensorflow:loss = 5.326588, step = 701 (0.316 sec)
# INFO:tensorflow:global_step/sec: 270.586
# INFO:tensorflow:loss = 3.5616407, step = 801 (0.370 sec)
# INFO:tensorflow:global_step/sec: 305.852
# INFO:tensorflow:loss = 3.5472608, step = 901 (0.330 sec)
# INFO:tensorflow:global_step/sec: 289.176
# INFO:tensorflow:loss = 5.308009, step = 1001 (0.343 sec)
# INFO:tensorflow:global_step/sec: 343.144
# INFO:tensorflow:loss = 3.2471476, step = 1101 (0.291 sec)
# INFO:tensorflow:global_step/sec: 332.338
# INFO:tensorflow:loss = 1.7393025, step = 1201 (0.301 sec)
# INFO:tensorflow:global_step/sec: 340.83
# INFO:tensorflow:loss = 7.621153, step = 1301 (0.293 sec)
# INFO:tensorflow:global_step/sec: 324.674
# INFO:tensorflow:loss = 4.4440703, step = 1401 (0.311 sec)
# INFO:tensorflow:global_step/sec: 278.066
# INFO:tensorflow:loss = 8.833588, step = 1501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 337.503
# INFO:tensorflow:loss = 6.4846, step = 1601 (0.296 sec)
# INFO:tensorflow:global_step/sec: 332.965
# INFO:tensorflow:loss = 1.3688798, step = 1701 (0.300 sec)
# INFO:tensorflow:global_step/sec: 301.374
# INFO:tensorflow:loss = 8.051659, step = 1801 (0.332 sec)
# INFO:tensorflow:global_step/sec: 270.771
# INFO:tensorflow:loss = 6.440572, step = 1901 (0.371 sec)
# INFO:tensorflow:global_step/sec: 310.156
# INFO:tensorflow:loss = 2.7557888, step = 2001 (0.322 sec)
# INFO:tensorflow:global_step/sec: 338.02
# INFO:tensorflow:loss = 2.7008336, step = 2101 (0.294 sec)
# INFO:tensorflow:global_step/sec: 273.125
# INFO:tensorflow:loss = 8.0978985, step = 2201 (0.369 sec)
# INFO:tensorflow:global_step/sec: 320.689
# INFO:tensorflow:loss = 1.1877201, step = 2301 (0.311 sec)
# INFO:tensorflow:global_step/sec: 346.394
# INFO:tensorflow:loss = 2.3070464, step = 2401 (0.289 sec)
# INFO:tensorflow:global_step/sec: 330.746
# INFO:tensorflow:loss = 1.786859, step = 2501 (0.300 sec)
# INFO:tensorflow:global_step/sec: 329.034
# INFO:tensorflow:loss = 2.1727102, step = 2601 (0.306 sec)
# INFO:tensorflow:global_step/sec: 285.387
# INFO:tensorflow:loss = 5.1974664, step = 2701 (0.350 sec)
# INFO:tensorflow:global_step/sec: 346.934
# INFO:tensorflow:loss = 5.202467, step = 2801 (0.286 sec)
# INFO:tensorflow:global_step/sec: 302.34
# INFO:tensorflow:loss = 12.756352, step = 2901 (0.332 sec)
# INFO:tensorflow:global_step/sec: 267.006
# INFO:tensorflow:loss = 4.6114826, step = 3001 (0.373 sec)
# INFO:tensorflow:global_step/sec: 301.802
# INFO:tensorflow:loss = 5.032915, step = 3101 (0.333 sec)
# INFO:tensorflow:global_step/sec: 264.726
# INFO:tensorflow:loss = 1.5043229, step = 3201 (0.381 sec)
# INFO:tensorflow:global_step/sec: 348.243
# INFO:tensorflow:loss = 1.9262958, step = 3301 (0.298 sec)
# INFO:tensorflow:global_step/sec: 345.366
# INFO:tensorflow:loss = 4.6662917, step = 3401 (0.290 sec)
# INFO:tensorflow:global_step/sec: 314.226
# INFO:tensorflow:loss = 1.5116744, step = 3501 (0.303 sec)
# INFO:tensorflow:global_step/sec: 350.863
# INFO:tensorflow:loss = 0.72464496, step = 3601 (0.285 sec)
# INFO:tensorflow:global_step/sec: 289.109
# INFO:tensorflow:loss = 3.3865955, step = 3701 (0.349 sec)
# INFO:tensorflow:global_step/sec: 317.171
# INFO:tensorflow:loss = 9.498576, step = 3801 (0.314 sec)
# INFO:tensorflow:global_step/sec: 300.629
# INFO:tensorflow:loss = 1.7633529, step = 3901 (0.331 sec)
# INFO:tensorflow:global_step/sec: 310.592
# INFO:tensorflow:loss = 2.8007033, step = 4001 (0.322 sec)
# INFO:tensorflow:global_step/sec: 269.423
# INFO:tensorflow:loss = 1.505311, step = 4101 (0.374 sec)
# INFO:tensorflow:global_step/sec: 299.935
# INFO:tensorflow:loss = 0.51030797, step = 4201 (0.332 sec)
# INFO:tensorflow:global_step/sec: 323.889
# INFO:tensorflow:loss = 6.0217066, step = 4301 (0.309 sec)
# INFO:tensorflow:global_step/sec: 325.583
# INFO:tensorflow:loss = 0.73372215, step = 4401 (0.306 sec)
# INFO:tensorflow:global_step/sec: 318.743
# INFO:tensorflow:loss = 0.39176416, step = 4501 (0.316 sec)
# INFO:tensorflow:global_step/sec: 301.741
# INFO:tensorflow:loss = 0.25220641, step = 4601 (0.331 sec)
# INFO:tensorflow:global_step/sec: 329.316
# INFO:tensorflow:loss = 1.7911237, step = 4701 (0.304 sec)
# INFO:tensorflow:global_step/sec: 350.252
# INFO:tensorflow:loss = 0.3041039, step = 4801 (0.299 sec)
# INFO:tensorflow:global_step/sec: 315.391
# INFO:tensorflow:loss = 4.006593, step = 4901 (0.303 sec)
# INFO:tensorflow:global_step/sec: 308.479
# INFO:tensorflow:loss = 11.440742, step = 5001 (0.323 sec)
# INFO:tensorflow:global_step/sec: 319.924
# INFO:tensorflow:loss = 0.93186164, step = 5101 (0.313 sec)
# INFO:tensorflow:global_step/sec: 283.234
# INFO:tensorflow:loss = 1.113692, step = 5201 (0.367 sec)
# INFO:tensorflow:global_step/sec: 267.342
# INFO:tensorflow:loss = 1.8629832, step = 5301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 318.645
# INFO:tensorflow:loss = 2.758434, step = 5401 (0.312 sec)
# INFO:tensorflow:global_step/sec: 327.631
# INFO:tensorflow:loss = 5.803428, step = 5501 (0.305 sec)
# INFO:tensorflow:global_step/sec: 317.453
# INFO:tensorflow:loss = 1.8450423, step = 5601 (0.317 sec)
# INFO:tensorflow:global_step/sec: 331.831
# INFO:tensorflow:loss = 2.044645, step = 5701 (0.299 sec)
# INFO:tensorflow:global_step/sec: 271.079
# INFO:tensorflow:loss = 0.16553625, step = 5801 (0.371 sec)
# INFO:tensorflow:global_step/sec: 314.712
# INFO:tensorflow:loss = 0.69580114, step = 5901 (0.331 sec)
# INFO:tensorflow:global_step/sec: 309.543
# INFO:tensorflow:loss = 0.76652163, step = 6001 (0.307 sec)
# INFO:tensorflow:global_step/sec: 243.529
# INFO:tensorflow:loss = 0.76544744, step = 6101 (0.414 sec)
# INFO:tensorflow:global_step/sec: 313.571
# INFO:tensorflow:loss = 2.715458, step = 6201 (0.316 sec)
# INFO:tensorflow:global_step/sec: 256.769
# INFO:tensorflow:loss = 1.4937918, step = 6301 (0.392 sec)
# INFO:tensorflow:global_step/sec: 288.983
# INFO:tensorflow:loss = 0.12821777, step = 6401 (0.343 sec)
# INFO:tensorflow:global_step/sec: 306.249
# INFO:tensorflow:loss = 1.029129, step = 6501 (0.327 sec)
# INFO:tensorflow:global_step/sec: 265.96
# INFO:tensorflow:loss = 0.9733986, step = 6601 (0.379 sec)
# INFO:tensorflow:global_step/sec: 336.206
# INFO:tensorflow:loss = 0.58823776, step = 6701 (0.294 sec)
# INFO:tensorflow:global_step/sec: 342.601
# INFO:tensorflow:loss = 2.4018426, step = 6801 (0.307 sec)
# INFO:tensorflow:global_step/sec: 310.893
# INFO:tensorflow:loss = 3.612802, step = 6901 (0.309 sec)
# INFO:tensorflow:global_step/sec: 276.401
# INFO:tensorflow:loss = 0.23617141, step = 7001 (0.362 sec)
# INFO:tensorflow:global_step/sec: 339.671
# INFO:tensorflow:loss = 1.2245857, step = 7101 (0.292 sec)
# INFO:tensorflow:global_step/sec: 328.598
# INFO:tensorflow:loss = 0.6718115, step = 7201 (0.306 sec)
# INFO:tensorflow:global_step/sec: 335.055
# INFO:tensorflow:loss = 0.33291692, step = 7301 (0.296 sec)
# INFO:tensorflow:global_step/sec: 247.225
# INFO:tensorflow:loss = 0.38439348, step = 7401 (0.409 sec)
# INFO:tensorflow:global_step/sec: 291.271
# INFO:tensorflow:loss = 1.5247939, step = 7501 (0.338 sec)
# INFO:tensorflow:global_step/sec: 331.771
# INFO:tensorflow:loss = 5.8704176, step = 7601 (0.301 sec)
# INFO:tensorflow:global_step/sec: 337.287
# INFO:tensorflow:loss = 1.3048997, step = 7701 (0.296 sec)
# INFO:tensorflow:global_step/sec: 284.008
# INFO:tensorflow:loss = 1.3587866, step = 7801 (0.352 sec)
# INFO:tensorflow:global_step/sec: 314.944
# INFO:tensorflow:loss = 0.2565527, step = 7901 (0.320 sec)
# INFO:tensorflow:global_step/sec: 318.26
# INFO:tensorflow:loss = 0.3808904, step = 8001 (0.312 sec)
# INFO:tensorflow:global_step/sec: 284.097
# INFO:tensorflow:loss = 0.5098706, step = 8101 (0.352 sec)
# INFO:tensorflow:global_step/sec: 314.907
# INFO:tensorflow:loss = 0.84212404, step = 8201 (0.318 sec)
# INFO:tensorflow:global_step/sec: 336.999
# INFO:tensorflow:loss = 1.1911765, step = 8301 (0.297 sec)
# INFO:tensorflow:global_step/sec: 260.977
# INFO:tensorflow:loss = 0.621176, step = 8401 (0.386 sec)
# INFO:tensorflow:global_step/sec: 270.437
# INFO:tensorflow:loss = 0.30834192, step = 8501 (0.367 sec)
# INFO:tensorflow:global_step/sec: 302.64
# INFO:tensorflow:loss = 0.25839424, step = 8601 (0.330 sec)
# INFO:tensorflow:global_step/sec: 323.119
# INFO:tensorflow:loss = 2.503171, step = 8701 (0.311 sec)
# INFO:tensorflow:global_step/sec: 334.486
# INFO:tensorflow:loss = 0.4627908, step = 8801 (0.297 sec)
# INFO:tensorflow:global_step/sec: 323.053
# INFO:tensorflow:loss = 0.45720044, step = 8901 (0.310 sec)
# INFO:tensorflow:global_step/sec: 281.044
# INFO:tensorflow:loss = 1.1823292, step = 9001 (0.358 sec)
# INFO:tensorflow:global_step/sec: 292.478
# INFO:tensorflow:loss = 0.2659555, step = 9101 (0.342 sec)
# INFO:tensorflow:global_step/sec: 329.592
# INFO:tensorflow:loss = 0.16091923, step = 9201 (0.304 sec)
# INFO:tensorflow:global_step/sec: 324.183
# INFO:tensorflow:loss = 0.3940344, step = 9301 (0.305 sec)
# INFO:tensorflow:global_step/sec: 325.351
# INFO:tensorflow:loss = 0.64414144, step = 9401 (0.307 sec)
# INFO:tensorflow:global_step/sec: 249.998
# INFO:tensorflow:loss = 2.7244775, step = 9501 (0.403 sec)
# INFO:tensorflow:global_step/sec: 275.405
# INFO:tensorflow:loss = 0.46533203, step = 9601 (0.365 sec)
# INFO:tensorflow:global_step/sec: 286.07
# INFO:tensorflow:loss = 0.39243847, step = 9701 (0.347 sec)
# INFO:tensorflow:global_step/sec: 330.347
# INFO:tensorflow:loss = 0.95770425, step = 9801 (0.301 sec)
# INFO:tensorflow:global_step/sec: 333.395
# INFO:tensorflow:loss = 0.8048396, step = 9901 (0.300 sec)
# INFO:tensorflow:global_step/sec: 311.409
# INFO:tensorflow:loss = 1.7472535, step = 10001 (0.321 sec)
# INFO:tensorflow:global_step/sec: 279.579
# INFO:tensorflow:loss = 0.6215954, step = 10101 (0.360 sec)
# INFO:tensorflow:global_step/sec: 319.856
# INFO:tensorflow:loss = 0.1463009, step = 10201 (0.311 sec)
# INFO:tensorflow:global_step/sec: 318.882
# INFO:tensorflow:loss = 0.2278531, step = 10301 (0.314 sec)
# INFO:tensorflow:global_step/sec: 321.302
# INFO:tensorflow:loss = 0.2577497, step = 10401 (0.311 sec)
# INFO:tensorflow:global_step/sec: 334.928
# INFO:tensorflow:loss = 0.63386154, step = 10501 (0.301 sec)
# INFO:tensorflow:global_step/sec: 324.423
# INFO:tensorflow:loss = 7.213933, step = 10601 (0.306 sec)
# INFO:tensorflow:global_step/sec: 223.93
# INFO:tensorflow:loss = 0.19391643, step = 10701 (0.449 sec)
# INFO:tensorflow:global_step/sec: 297.271
# INFO:tensorflow:loss = 0.7363667, step = 10801 (0.334 sec)
# INFO:tensorflow:global_step/sec: 332.963
# INFO:tensorflow:loss = 0.102908954, step = 10901 (0.316 sec)
# INFO:tensorflow:global_step/sec: 322.678
# INFO:tensorflow:loss = 0.58030325, step = 11001 (0.294 sec)
# INFO:tensorflow:global_step/sec: 342.042
# INFO:tensorflow:loss = 0.035707414, step = 11101 (0.292 sec)
# INFO:tensorflow:global_step/sec: 316.182
# INFO:tensorflow:loss = 0.2287913, step = 11201 (0.316 sec)
# INFO:tensorflow:global_step/sec: 284.865
# INFO:tensorflow:loss = 0.16885549, step = 11301 (0.355 sec)
# INFO:tensorflow:global_step/sec: 326.197
# INFO:tensorflow:loss = 0.025517749, step = 11401 (0.305 sec)
# INFO:tensorflow:global_step/sec: 320.714
# INFO:tensorflow:loss = 0.953476, step = 11501 (0.310 sec)
# INFO:tensorflow:global_step/sec: 332.883
# INFO:tensorflow:loss = 0.28196925, step = 11601 (0.300 sec)
# INFO:tensorflow:global_step/sec: 311.502
# INFO:tensorflow:loss = 0.24463204, step = 11701 (0.321 sec)
# INFO:tensorflow:global_step/sec: 274.93
# INFO:tensorflow:loss = 0.23435168, step = 11801 (0.381 sec)
# INFO:tensorflow:global_step/sec: 268.755
# INFO:tensorflow:loss = 0.18967754, step = 11901 (0.356 sec)
# INFO:tensorflow:global_step/sec: 312.9
# INFO:tensorflow:loss = 0.10355736, step = 12001 (0.320 sec)
# INFO:tensorflow:global_step/sec: 251.4
# INFO:tensorflow:loss = 0.5325237, step = 12101 (0.399 sec)
# INFO:tensorflow:global_step/sec: 270.482
# INFO:tensorflow:loss = 0.4846813, step = 12201 (0.367 sec)
# INFO:tensorflow:global_step/sec: 262.017
# INFO:tensorflow:loss = 0.19858545, step = 12301 (0.386 sec)
# INFO:tensorflow:global_step/sec: 271.895
# INFO:tensorflow:loss = 0.01518639, step = 12401 (0.367 sec)
# INFO:tensorflow:global_step/sec: 271.157
# INFO:tensorflow:loss = 0.24667053, step = 12501 (0.367 sec)
# INFO:tensorflow:global_step/sec: 266.448
# INFO:tensorflow:loss = 0.7655854, step = 12601 (0.376 sec)
# INFO:tensorflow:global_step/sec: 283.447
# INFO:tensorflow:loss = 0.31936035, step = 12701 (0.354 sec)
# INFO:tensorflow:global_step/sec: 262.716
# INFO:tensorflow:loss = 1.83112, step = 12801 (0.378 sec)
# INFO:tensorflow:global_step/sec: 316.923
# INFO:tensorflow:loss = 0.40786698, step = 12901 (0.331 sec)
# INFO:tensorflow:global_step/sec: 301.252
# INFO:tensorflow:loss = 0.22921959, step = 13001 (0.319 sec)
# INFO:tensorflow:global_step/sec: 321.687
# INFO:tensorflow:loss = 0.16589126, step = 13101 (0.311 sec)
# INFO:tensorflow:global_step/sec: 271.044
# INFO:tensorflow:loss = 0.69376206, step = 13201 (0.366 sec)
# INFO:tensorflow:global_step/sec: 283.463
# INFO:tensorflow:loss = 0.045898166, step = 13301 (0.355 sec)
# INFO:tensorflow:global_step/sec: 273.373
# INFO:tensorflow:loss = 0.1907439, step = 13401 (0.367 sec)
# INFO:tensorflow:global_step/sec: 271.165
# INFO:tensorflow:loss = 0.4235722, step = 13501 (0.370 sec)
# INFO:tensorflow:global_step/sec: 288.349
# INFO:tensorflow:loss = 0.18457326, step = 13601 (0.346 sec)
# INFO:tensorflow:global_step/sec: 264.003
# INFO:tensorflow:loss = 0.013200619, step = 13701 (0.378 sec)
# INFO:tensorflow:global_step/sec: 248.281
# INFO:tensorflow:loss = 0.12863249, step = 13801 (0.405 sec)
# INFO:tensorflow:global_step/sec: 250.143
# INFO:tensorflow:loss = 0.09190421, step = 13901 (0.398 sec)
# INFO:tensorflow:global_step/sec: 285.877
# INFO:tensorflow:loss = 0.41749164, step = 14001 (0.350 sec)
# INFO:tensorflow:global_step/sec: 329.259
# INFO:tensorflow:loss = 0.27272394, step = 14101 (0.302 sec)
# INFO:tensorflow:global_step/sec: 314.27
# INFO:tensorflow:loss = 0.076614924, step = 14201 (0.318 sec)
# INFO:tensorflow:global_step/sec: 333.108
# INFO:tensorflow:loss = 0.5218404, step = 14301 (0.300 sec)
# INFO:tensorflow:global_step/sec: 316.24
# INFO:tensorflow:loss = 0.15918571, step = 14401 (0.316 sec)
# INFO:tensorflow:global_step/sec: 303.193
# INFO:tensorflow:loss = 0.11084022, step = 14501 (0.333 sec)
# INFO:tensorflow:global_step/sec: 274.881
# INFO:tensorflow:loss = 0.20325717, step = 14601 (0.363 sec)
# INFO:tensorflow:global_step/sec: 330.458
# INFO:tensorflow:loss = 0.207778, step = 14701 (0.301 sec)
# INFO:tensorflow:global_step/sec: 303.215
# INFO:tensorflow:loss = 0.060600337, step = 14801 (0.333 sec)
# INFO:tensorflow:global_step/sec: 272.68
# INFO:tensorflow:loss = 0.06753541, step = 14901 (0.367 sec)
# INFO:tensorflow:global_step/sec: 278.711
# INFO:tensorflow:loss = 0.10640932, step = 15001 (0.357 sec)
# INFO:tensorflow:global_step/sec: 332.035
# INFO:tensorflow:loss = 0.011492984, step = 15101 (0.300 sec)
# INFO:tensorflow:global_step/sec: 290.501
# INFO:tensorflow:loss = 0.15888111, step = 15201 (0.346 sec)
# INFO:tensorflow:global_step/sec: 327.088
# INFO:tensorflow:loss = 0.056837384, step = 15301 (0.304 sec)
# INFO:tensorflow:global_step/sec: 316.463
# INFO:tensorflow:loss = 0.104069725, step = 15401 (0.316 sec)
# INFO:tensorflow:global_step/sec: 298.96
# INFO:tensorflow:loss = 0.11440698, step = 15501 (0.334 sec)
# INFO:tensorflow:global_step/sec: 333.671
# INFO:tensorflow:loss = 0.29308295, step = 15601 (0.300 sec)
# INFO:tensorflow:global_step/sec: 267.002
# INFO:tensorflow:loss = 0.07249571, step = 15701 (0.377 sec)
# INFO:tensorflow:global_step/sec: 290.019
# INFO:tensorflow:loss = 0.057936475, step = 15801 (0.346 sec)
# INFO:tensorflow:global_step/sec: 259.217
# INFO:tensorflow:loss = 0.847804, step = 15901 (0.386 sec)
# INFO:tensorflow:global_step/sec: 235.984
# INFO:tensorflow:loss = 0.03624999, step = 16001 (0.423 sec)
# INFO:tensorflow:global_step/sec: 273.383
# INFO:tensorflow:loss = 0.06259473, step = 16101 (0.366 sec)
# INFO:tensorflow:global_step/sec: 268.971
# INFO:tensorflow:loss = 0.07835274, step = 16201 (0.372 sec)
# INFO:tensorflow:global_step/sec: 263.308
# INFO:tensorflow:loss = 0.16941412, step = 16301 (0.382 sec)
# INFO:tensorflow:global_step/sec: 315.552
# INFO:tensorflow:loss = 2.1730573, step = 16401 (0.315 sec)
# INFO:tensorflow:global_step/sec: 274.882
# INFO:tensorflow:loss = 0.1593946, step = 16501 (0.366 sec)
# INFO:tensorflow:global_step/sec: 301.379
# INFO:tensorflow:loss = 0.18374616, step = 16601 (0.330 sec)
# INFO:tensorflow:global_step/sec: 317.215
# INFO:tensorflow:loss = 0.10226478, step = 16701 (0.313 sec)
# INFO:tensorflow:global_step/sec: 288.352
# INFO:tensorflow:loss = 0.06516072, step = 16801 (0.351 sec)
# INFO:tensorflow:global_step/sec: 299.572
# INFO:tensorflow:loss = 0.19193771, step = 16901 (0.334 sec)
# INFO:tensorflow:global_step/sec: 252.67
# INFO:tensorflow:loss = 0.013259938, step = 17001 (0.395 sec)
# INFO:tensorflow:global_step/sec: 263.309
# INFO:tensorflow:loss = 0.09845054, step = 17101 (0.379 sec)
# INFO:tensorflow:global_step/sec: 280.272
# INFO:tensorflow:loss = 0.14803255, step = 17201 (0.359 sec)
# INFO:tensorflow:global_step/sec: 317.765
# INFO:tensorflow:loss = 0.031508587, step = 17301 (0.311 sec)
# INFO:tensorflow:global_step/sec: 340.515
# INFO:tensorflow:loss = 0.20654431, step = 17401 (0.294 sec)
# INFO:tensorflow:global_step/sec: 333.421
# INFO:tensorflow:loss = 0.045559444, step = 17501 (0.300 sec)
# INFO:tensorflow:global_step/sec: 318.889
# INFO:tensorflow:loss = 0.027650606, step = 17601 (0.314 sec)
# INFO:tensorflow:global_step/sec: 307.353
# INFO:tensorflow:loss = 0.2659089, step = 17701 (0.328 sec)
# INFO:tensorflow:global_step/sec: 307.868
# INFO:tensorflow:loss = 0.043203935, step = 17801 (0.325 sec)
# INFO:tensorflow:global_step/sec: 275.64
# INFO:tensorflow:loss = 0.049498834, step = 17901 (0.362 sec)
# INFO:tensorflow:global_step/sec: 297.788
# INFO:tensorflow:loss = 0.083702005, step = 18001 (0.337 sec)
# INFO:tensorflow:global_step/sec: 273.281
# INFO:tensorflow:loss = 0.013095945, step = 18101 (0.363 sec)
# INFO:tensorflow:global_step/sec: 301.294
# INFO:tensorflow:loss = 0.21819592, step = 18201 (0.332 sec)
# INFO:tensorflow:global_step/sec: 306.806
# INFO:tensorflow:loss = 0.31217307, step = 18301 (0.328 sec)
# INFO:tensorflow:global_step/sec: 320.696
# INFO:tensorflow:loss = 0.052900113, step = 18401 (0.312 sec)
# INFO:tensorflow:global_step/sec: 318.094
# INFO:tensorflow:loss = 0.14631683, step = 18501 (0.314 sec)
# INFO:tensorflow:global_step/sec: 280.798
# INFO:tensorflow:loss = 0.003275036, step = 18601 (0.358 sec)
# INFO:tensorflow:global_step/sec: 342.165
# INFO:tensorflow:loss = 0.06036215, step = 18701 (0.304 sec)
# INFO:tensorflow:global_step/sec: 298.76
# INFO:tensorflow:loss = 0.04432611, step = 18801 (0.321 sec)
# INFO:tensorflow:global_step/sec: 327.852
# INFO:tensorflow:loss = 0.055013385, step = 18901 (0.305 sec)
# INFO:tensorflow:global_step/sec: 310.737
# INFO:tensorflow:loss = 0.08838765, step = 19001 (0.323 sec)
# INFO:tensorflow:global_step/sec: 309.694
# INFO:tensorflow:loss = 0.22461501, step = 19101 (0.320 sec)
# INFO:tensorflow:global_step/sec: 249.064
# INFO:tensorflow:loss = 0.03145126, step = 19201 (0.409 sec)
# INFO:tensorflow:global_step/sec: 273.953
# INFO:tensorflow:loss = 0.17571054, step = 19301 (0.360 sec)
# INFO:tensorflow:global_step/sec: 327.028
# INFO:tensorflow:loss = 0.39158666, step = 19401 (0.304 sec)
# INFO:tensorflow:global_step/sec: 334.325
# INFO:tensorflow:loss = 0.040967252, step = 19501 (0.299 sec)
# INFO:tensorflow:global_step/sec: 306.283
# INFO:tensorflow:loss = 0.20054844, step = 19601 (0.328 sec)
# INFO:tensorflow:global_step/sec: 326.935
# INFO:tensorflow:loss = 0.08043328, step = 19701 (0.306 sec)
# INFO:tensorflow:global_step/sec: 321.511
# INFO:tensorflow:loss = 0.042165846, step = 19801 (0.311 sec)
# INFO:tensorflow:global_step/sec: 314.642
# INFO:tensorflow:loss = 0.09890331, step = 19901 (0.319 sec)
# INFO:tensorflow:global_step/sec: 320.701
# INFO:tensorflow:loss = 0.32431126, step = 20001 (0.309 sec)
# INFO:tensorflow:global_step/sec: 276.957
# INFO:tensorflow:loss = 0.032446764, step = 20101 (0.363 sec)
# INFO:tensorflow:global_step/sec: 324.146
# INFO:tensorflow:loss = 0.08212304, step = 20201 (0.309 sec)
# INFO:tensorflow:global_step/sec: 269.697
# INFO:tensorflow:loss = 0.18221442, step = 20301 (0.372 sec)
# INFO:tensorflow:global_step/sec: 277.166
# INFO:tensorflow:loss = 0.029954683, step = 20401 (0.360 sec)
# INFO:tensorflow:global_step/sec: 311.705
# INFO:tensorflow:loss = 0.09457987, step = 20501 (0.321 sec)
# INFO:tensorflow:global_step/sec: 319.35
# INFO:tensorflow:loss = 0.06529947, step = 20601 (0.313 sec)
# INFO:tensorflow:global_step/sec: 319.001
# INFO:tensorflow:loss = 0.051009007, step = 20701 (0.315 sec)
# INFO:tensorflow:global_step/sec: 286.699
# INFO:tensorflow:loss = 0.017569717, step = 20801 (0.348 sec)
# INFO:tensorflow:global_step/sec: 325.029
# INFO:tensorflow:loss = 0.028415956, step = 20901 (0.305 sec)
# INFO:tensorflow:global_step/sec: 307.48
# INFO:tensorflow:loss = 0.057083, step = 21001 (0.327 sec)
# INFO:tensorflow:global_step/sec: 285.063
# INFO:tensorflow:loss = 0.012147564, step = 21101 (0.351 sec)
# INFO:tensorflow:global_step/sec: 314.646
# INFO:tensorflow:loss = 0.07647079, step = 21201 (0.318 sec)
# INFO:tensorflow:global_step/sec: 287.522
# INFO:tensorflow:loss = 0.028503276, step = 21301 (0.350 sec)
# INFO:tensorflow:global_step/sec: 259.888
# INFO:tensorflow:loss = 0.025719734, step = 21401 (0.384 sec)
# INFO:tensorflow:global_step/sec: 282.382
# INFO:tensorflow:loss = 0.1087678, step = 21501 (0.351 sec)
# INFO:tensorflow:global_step/sec: 319.237
# INFO:tensorflow:loss = 0.015327782, step = 21601 (0.315 sec)
# INFO:tensorflow:global_step/sec: 329.406
# INFO:tensorflow:loss = 0.047934197, step = 21701 (0.302 sec)
# INFO:tensorflow:global_step/sec: 271.217
# INFO:tensorflow:loss = 0.08197454, step = 21801 (0.373 sec)
# INFO:tensorflow:global_step/sec: 289.181
# INFO:tensorflow:loss = 0.196406, step = 21901 (0.344 sec)
# INFO:tensorflow:global_step/sec: 305.057
# INFO:tensorflow:loss = 0.029608464, step = 22001 (0.328 sec)
# INFO:tensorflow:global_step/sec: 291.712
# INFO:tensorflow:loss = 0.045423795, step = 22101 (0.343 sec)
# INFO:tensorflow:global_step/sec: 316.994
# INFO:tensorflow:loss = 0.0220997, step = 22201 (0.315 sec)
# INFO:tensorflow:global_step/sec: 335.709
# INFO:tensorflow:loss = 0.06828871, step = 22301 (0.296 sec)
# INFO:tensorflow:global_step/sec: 289.412
# INFO:tensorflow:loss = 0.095886275, step = 22401 (0.349 sec)
# INFO:tensorflow:global_step/sec: 264.004
# INFO:tensorflow:loss = 0.16202465, step = 22501 (0.379 sec)
# INFO:tensorflow:global_step/sec: 292.743
# INFO:tensorflow:loss = 0.09103072, step = 22601 (0.339 sec)
# INFO:tensorflow:global_step/sec: 316.533
# INFO:tensorflow:loss = 0.025910653, step = 22701 (0.318 sec)
# INFO:tensorflow:global_step/sec: 327.694
# INFO:tensorflow:loss = 0.021004504, step = 22801 (0.303 sec)
# INFO:tensorflow:global_step/sec: 306.658
# INFO:tensorflow:loss = 0.07806501, step = 22901 (0.328 sec)
# INFO:tensorflow:global_step/sec: 317.166
# INFO:tensorflow:loss = 0.03241463, step = 23001 (0.315 sec)
# INFO:tensorflow:global_step/sec: 317.642
# INFO:tensorflow:loss = 0.042591747, step = 23101 (0.315 sec)
# INFO:tensorflow:global_step/sec: 309.453
# INFO:tensorflow:loss = 0.04510494, step = 23201 (0.323 sec)
# INFO:tensorflow:global_step/sec: 329.421
# INFO:tensorflow:loss = 0.029292868, step = 23301 (0.302 sec)
# INFO:tensorflow:global_step/sec: 307.741
# INFO:tensorflow:loss = 0.024887871, step = 23401 (0.328 sec)
# INFO:tensorflow:global_step/sec: 321.921
# INFO:tensorflow:loss = 0.026107779, step = 23501 (0.308 sec)
# INFO:tensorflow:global_step/sec: 257.2
# INFO:tensorflow:loss = 0.030456983, step = 23601 (0.393 sec)
# INFO:tensorflow:global_step/sec: 285.067
# INFO:tensorflow:loss = 0.03446884, step = 23701 (0.350 sec)
# INFO:tensorflow:global_step/sec: 322.765
# INFO:tensorflow:loss = 0.042272404, step = 23801 (0.309 sec)
# INFO:tensorflow:global_step/sec: 313.658
# INFO:tensorflow:loss = 0.012376662, step = 23901 (0.319 sec)
# INFO:tensorflow:global_step/sec: 308.818
# INFO:tensorflow:loss = 0.03966806, step = 24001 (0.324 sec)
# INFO:tensorflow:global_step/sec: 310.738
# INFO:tensorflow:loss = 0.060012624, step = 24101 (0.322 sec)
# INFO:tensorflow:global_step/sec: 330.548
# INFO:tensorflow:loss = 0.046957772, step = 24201 (0.301 sec)
# INFO:tensorflow:global_step/sec: 304.089
# INFO:tensorflow:loss = 0.0191703, step = 24301 (0.332 sec)
# INFO:tensorflow:global_step/sec: 316.635
# INFO:tensorflow:loss = 0.09615418, step = 24401 (0.315 sec)
# INFO:tensorflow:global_step/sec: 310.737
# INFO:tensorflow:loss = 0.010516002, step = 24501 (0.321 sec)
# INFO:tensorflow:global_step/sec: 303.204
# INFO:tensorflow:loss = 0.07754654, step = 24601 (0.331 sec)
# INFO:tensorflow:global_step/sec: 240.522
# INFO:tensorflow:loss = 0.0014943181, step = 24701 (0.417 sec)
# INFO:tensorflow:global_step/sec: 273.379
# INFO:tensorflow:loss = 0.029815797, step = 24801 (0.368 sec)
# INFO:tensorflow:global_step/sec: 290.023
# INFO:tensorflow:loss = 0.16976552, step = 24901 (0.343 sec)
# INFO:tensorflow:global_step/sec: 295.153
# INFO:tensorflow:loss = 0.008138146, step = 25001 (0.338 sec)
# INFO:tensorflow:global_step/sec: 300.473
# INFO:tensorflow:loss = 0.032847743, step = 25101 (0.333 sec)
# INFO:tensorflow:global_step/sec: 306.924
# INFO:tensorflow:loss = 0.06523929, step = 25201 (0.326 sec)
# INFO:tensorflow:global_step/sec: 262.617
# INFO:tensorflow:loss = 0.0551019, step = 25301 (0.381 sec)
# INFO:tensorflow:global_step/sec: 301.299
# INFO:tensorflow:loss = 0.02621803, step = 25401 (0.330 sec)
# INFO:tensorflow:global_step/sec: 304.683
# INFO:tensorflow:loss = 0.007585174, step = 25501 (0.330 sec)
# INFO:tensorflow:global_step/sec: 316.634
# INFO:tensorflow:loss = 0.008654072, step = 25601 (0.316 sec)
# INFO:tensorflow:global_step/sec: 281.061
# INFO:tensorflow:loss = 0.013693995, step = 25701 (0.357 sec)
# INFO:tensorflow:global_step/sec: 255.248
# INFO:tensorflow:loss = 0.029335894, step = 25801 (0.391 sec)
# INFO:tensorflow:global_step/sec: 324.053
# INFO:tensorflow:loss = 0.013381727, step = 25901 (0.307 sec)
# INFO:tensorflow:global_step/sec: 304.009
# INFO:tensorflow:loss = 0.044429433, step = 26001 (0.332 sec)
# INFO:tensorflow:global_step/sec: 305.05
# INFO:tensorflow:loss = 0.028488623, step = 26101 (0.327 sec)
# INFO:tensorflow:global_step/sec: 309.776
# INFO:tensorflow:loss = 0.014427401, step = 26201 (0.323 sec)
# INFO:tensorflow:global_step/sec: 307.867
# INFO:tensorflow:loss = 0.033279244, step = 26301 (0.325 sec)
# INFO:tensorflow:global_step/sec: 312.678
# INFO:tensorflow:loss = 0.058359146, step = 26401 (0.320 sec)
# INFO:tensorflow:global_step/sec: 320.927
# INFO:tensorflow:loss = 0.02608341, step = 26501 (0.312 sec)
# INFO:tensorflow:global_step/sec: 309.773
# INFO:tensorflow:loss = 0.0067666983, step = 26601 (0.324 sec)
# INFO:tensorflow:global_step/sec: 304.126
# INFO:tensorflow:loss = 0.030802187, step = 26701 (0.329 sec)
# INFO:tensorflow:global_step/sec: 271.894
# INFO:tensorflow:loss = 0.013141214, step = 26801 (0.367 sec)
# INFO:tensorflow:global_step/sec: 232.691
# INFO:tensorflow:loss = 0.04531598, step = 26901 (0.432 sec)
# INFO:tensorflow:global_step/sec: 275.64
# INFO:tensorflow:loss = 0.054257076, step = 27001 (0.362 sec)
# INFO:tensorflow:global_step/sec: 277.935
# INFO:tensorflow:loss = 0.05418043, step = 27101 (0.359 sec)
# INFO:tensorflow:global_step/sec: 271.895
# INFO:tensorflow:loss = 0.013072925, step = 27201 (0.368 sec)
# INFO:tensorflow:global_step/sec: 271.894
# INFO:tensorflow:loss = 0.031681694, step = 27301 (0.368 sec)
# INFO:tensorflow:global_step/sec: 271.159
# INFO:tensorflow:loss = 0.029033896, step = 27401 (0.369 sec)
# INFO:tensorflow:global_step/sec: 265.403
# INFO:tensorflow:loss = 0.030100003, step = 27501 (0.379 sec)
# INFO:tensorflow:global_step/sec: 273.381
# INFO:tensorflow:loss = 0.008335559, step = 27601 (0.365 sec)
# INFO:tensorflow:global_step/sec: 239.946
# INFO:tensorflow:loss = 0.02329326, step = 27701 (0.416 sec)
# INFO:tensorflow:global_step/sec: 223.842
# INFO:tensorflow:loss = 0.036853604, step = 27801 (0.455 sec)
# INFO:tensorflow:global_step/sec: 235.983
# INFO:tensorflow:loss = 0.07556492, step = 27901 (0.416 sec)
# INFO:tensorflow:global_step/sec: 256.557
# INFO:tensorflow:loss = 0.03828002, step = 28001 (0.390 sec)
# INFO:tensorflow:global_step/sec: 267.531
# INFO:tensorflow:loss = 0.045651175, step = 28101 (0.375 sec)
# INFO:tensorflow:global_step/sec: 264.004
# INFO:tensorflow:loss = 0.011059683, step = 28201 (0.379 sec)
# INFO:tensorflow:global_step/sec: 268.972
# INFO:tensorflow:loss = 0.022825684, step = 28301 (0.371 sec)
# INFO:tensorflow:global_step/sec: 263.308
# INFO:tensorflow:loss = 0.04270538, step = 28401 (0.384 sec)
# INFO:tensorflow:global_step/sec: 265.404
# INFO:tensorflow:loss = 0.015630761, step = 28501 (0.373 sec)
# INFO:tensorflow:global_step/sec: 267.533
# INFO:tensorflow:loss = 0.051833976, step = 28601 (0.376 sec)
# INFO:tensorflow:global_step/sec: 255.248
# INFO:tensorflow:loss = 0.01680531, step = 28701 (0.391 sec)
# INFO:tensorflow:global_step/sec: 234.326
# INFO:tensorflow:loss = 0.0549723, step = 28801 (0.426 sec)
# INFO:tensorflow:global_step/sec: 290.863
# INFO:tensorflow:loss = 0.013206955, step = 28901 (0.345 sec)
# INFO:tensorflow:global_step/sec: 311.705
# INFO:tensorflow:loss = 0.019759076, step = 29001 (0.320 sec)
# INFO:tensorflow:global_step/sec: 306.922
# INFO:tensorflow:loss = 0.07369554, step = 29101 (0.327 sec)
# INFO:tensorflow:global_step/sec: 299.574
# INFO:tensorflow:loss = 0.029176109, step = 29201 (0.334 sec)
# INFO:tensorflow:global_step/sec: 319.6
# INFO:tensorflow:loss = 0.084672235, step = 29301 (0.310 sec)
# INFO:tensorflow:global_step/sec: 318.151
# INFO:tensorflow:loss = 0.031545475, step = 29401 (0.317 sec)
# INFO:tensorflow:global_step/sec: 308.818
# INFO:tensorflow:loss = 0.030005496, step = 29501 (0.323 sec)
# INFO:tensorflow:global_step/sec: 308.819
# INFO:tensorflow:loss = 0.07742635, step = 29601 (0.325 sec)
# INFO:tensorflow:global_step/sec: 330.339
# INFO:tensorflow:loss = 0.025081668, step = 29701 (0.300 sec)
# INFO:tensorflow:global_step/sec: 278.178
# INFO:tensorflow:loss = 0.0542585, step = 29801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 260.356
# INFO:tensorflow:loss = 0.026728995, step = 29901 (0.386 sec)
# INFO:tensorflow:global_step/sec: 311.706
# INFO:tensorflow:loss = 0.05192495, step = 30001 (0.321 sec)
# INFO:tensorflow:global_step/sec: 314.644
# INFO:tensorflow:loss = 0.065029316, step = 30101 (0.318 sec)
# INFO:tensorflow:global_step/sec: 318.656
# INFO:tensorflow:loss = 0.0142825665, step = 30201 (0.315 sec)
# INFO:tensorflow:global_step/sec: 314.642
# INFO:tensorflow:loss = 0.04642711, step = 30301 (0.318 sec)
# INFO:tensorflow:global_step/sec: 314.648
# INFO:tensorflow:loss = 0.15887615, step = 30401 (0.317 sec)
# INFO:tensorflow:global_step/sec: 301.377
# INFO:tensorflow:loss = 0.01912181, step = 30501 (0.332 sec)
# INFO:tensorflow:global_step/sec: 308.819
# INFO:tensorflow:loss = 0.008215215, step = 30601 (0.325 sec)
# INFO:tensorflow:global_step/sec: 321.728
# INFO:tensorflow:loss = 0.034053672, step = 30701 (0.310 sec)
# INFO:tensorflow:global_step/sec: 308.818
# INFO:tensorflow:loss = 0.016394371, step = 30801 (0.325 sec)
# INFO:tensorflow:global_step/sec: 271.157
# INFO:tensorflow:loss = 0.057917066, step = 30901 (0.369 sec)
# INFO:tensorflow:global_step/sec: 265.403
# INFO:tensorflow:loss = 0.012590424, step = 31001 (0.375 sec)
# INFO:tensorflow:global_step/sec: 313.66
# INFO:tensorflow:loss = 0.080129884, step = 31101 (0.321 sec)
# INFO:tensorflow:global_step/sec: 318.653
# INFO:tensorflow:loss = 0.018138517, step = 31201 (0.314 sec)
# INFO:tensorflow:global_step/sec: 318.654
# INFO:tensorflow:loss = 0.0112710595, step = 31301 (0.313 sec)
# INFO:tensorflow:global_step/sec: 305.052
# INFO:tensorflow:loss = 0.06556987, step = 31401 (0.328 sec)
# INFO:tensorflow:global_step/sec: 313.659
# INFO:tensorflow:loss = 0.083278134, step = 31501 (0.319 sec)
# INFO:tensorflow:global_step/sec: 320.697
# INFO:tensorflow:loss = 0.038524088, step = 31601 (0.313 sec)
# INFO:tensorflow:global_step/sec: 306.91
# INFO:tensorflow:loss = 0.04540049, step = 31701 (0.325 sec)
# INFO:tensorflow:global_step/sec: 309.789
# INFO:tensorflow:loss = 0.027391098, step = 31801 (0.324 sec)
# INFO:tensorflow:global_step/sec: 318.654
# INFO:tensorflow:loss = 0.03179156, step = 31901 (0.314 sec)
# INFO:tensorflow:global_step/sec: 280.27
# INFO:tensorflow:loss = 0.0047290307, step = 32001 (0.357 sec)
# INFO:tensorflow:global_step/sec: 257.218
# INFO:tensorflow:loss = 0.023013934, step = 32101 (0.388 sec)
# INFO:tensorflow:global_step/sec: 313.659
# INFO:tensorflow:loss = 0.046587117, step = 32201 (0.319 sec)
# INFO:tensorflow:global_step/sec: 318.651
# INFO:tensorflow:loss = 0.040482484, step = 32301 (0.314 sec)
# INFO:tensorflow:global_step/sec: 311.706
# INFO:tensorflow:loss = 0.046570405, step = 32401 (0.321 sec)
# INFO:tensorflow:global_step/sec: 312.68
# INFO:tensorflow:loss = 0.03138489, step = 32501 (0.320 sec)
# INFO:tensorflow:global_step/sec: 313.658
# INFO:tensorflow:loss = 0.093612075, step = 32601 (0.319 sec)
# INFO:tensorflow:global_step/sec: 302.288
# INFO:tensorflow:loss = 0.04598008, step = 32701 (0.331 sec)
# INFO:tensorflow:global_step/sec: 315.637
# INFO:tensorflow:loss = 0.022406077, step = 32801 (0.318 sec)
# INFO:tensorflow:global_step/sec: 307.868
# INFO:tensorflow:loss = 0.009902868, step = 32901 (0.324 sec)
# INFO:tensorflow:global_step/sec: 311.705
# INFO:tensorflow:loss = 0.010503637, step = 33001 (0.321 sec)
# INFO:tensorflow:global_step/sec: 271.895
# INFO:tensorflow:loss = 0.008153386, step = 33101 (0.369 sec)
# INFO:tensorflow:global_step/sec: 268.25
# INFO:tensorflow:loss = 0.0242204, step = 33201 (0.373 sec)
# INFO:tensorflow:global_step/sec: 280.273
# INFO:tensorflow:loss = 0.045104966, step = 33301 (0.356 sec)
# INFO:tensorflow:global_step/sec: 310.735
# INFO:tensorflow:loss = 0.055412624, step = 33401 (0.322 sec)
# INFO:tensorflow:global_step/sec: 312.68
# INFO:tensorflow:loss = 0.027127815, step = 33501 (0.323 sec)
# INFO:tensorflow:global_step/sec: 306.925
# INFO:tensorflow:loss = 0.019180536, step = 33601 (0.323 sec)
# INFO:tensorflow:global_step/sec: 311.706
# INFO:tensorflow:loss = 0.016074212, step = 33701 (0.322 sec)
# INFO:tensorflow:global_step/sec: 307.868
# INFO:tensorflow:loss = 0.057565574, step = 33801 (0.324 sec)
# INFO:tensorflow:global_step/sec: 307.867
# INFO:tensorflow:loss = 0.045991756, step = 33901 (0.326 sec)
# INFO:tensorflow:global_step/sec: 311.706
# INFO:tensorflow:loss = 0.045432944, step = 34001 (0.321 sec)
# INFO:tensorflow:global_step/sec: 310.737
# INFO:tensorflow:loss = 0.031044275, step = 34101 (0.322 sec)
# INFO:tensorflow:global_step/sec: 266.11
# INFO:tensorflow:loss = 0.048024308, step = 34201 (0.376 sec)
# INFO:tensorflow:global_step/sec: 270.424
# INFO:tensorflow:loss = 0.01743571, step = 34301 (0.369 sec)
# INFO:tensorflow:global_step/sec: 315.639
# INFO:tensorflow:loss = 0.011522114, step = 34401 (0.318 sec)
# INFO:tensorflow:global_step/sec: 286.698
# INFO:tensorflow:loss = 0.059120677, step = 34501 (0.349 sec)
# INFO:tensorflow:global_step/sec: 305.052
# INFO:tensorflow:loss = 0.07258765, step = 34601 (0.328 sec)
# INFO:tensorflow:global_step/sec: 299.573
# INFO:tensorflow:loss = 0.025305383, step = 34701 (0.334 sec)
# INFO:tensorflow:global_step/sec: 313.658
# INFO:tensorflow:loss = 0.0017969636, step = 34801 (0.319 sec)
# INFO:tensorflow:global_step/sec: 315.637
# INFO:tensorflow:loss = 0.012230197, step = 34901 (0.317 sec)
# INFO:tensorflow:global_step/sec: 304.125
# INFO:tensorflow:loss = 0.0042318306, step = 35001 (0.328 sec)
# INFO:tensorflow:global_step/sec: 306.925
# INFO:tensorflow:loss = 0.019902552, step = 35101 (0.326 sec)
# INFO:tensorflow:global_step/sec: 303.202
# INFO:tensorflow:loss = 0.047129538, step = 35201 (0.331 sec)
# INFO:tensorflow:global_step/sec: 266.11
# INFO:tensorflow:loss = 0.012289593, step = 35301 (0.376 sec)
# INFO:tensorflow:global_step/sec: 280.273
# INFO:tensorflow:loss = 0.0081375465, step = 35401 (0.356 sec)
# INFO:tensorflow:global_step/sec: 312.679
# INFO:tensorflow:loss = 0.0071831895, step = 35501 (0.321 sec)
# INFO:tensorflow:global_step/sec: 306.925
# INFO:tensorflow:loss = 0.023916937, step = 35601 (0.335 sec)
# INFO:tensorflow:global_step/sec: 305.986
# INFO:tensorflow:loss = 0.0053602573, step = 35701 (0.318 sec)
# INFO:tensorflow:global_step/sec: 311.704
# INFO:tensorflow:loss = 0.026793573, step = 35801 (0.320 sec)
# INFO:tensorflow:global_step/sec: 305.05
# INFO:tensorflow:loss = 0.008112377, step = 35901 (0.328 sec)
# INFO:tensorflow:global_step/sec: 313.661
# INFO:tensorflow:loss = 0.007999109, step = 36001 (0.320 sec)
# INFO:tensorflow:global_step/sec: 308.816
# INFO:tensorflow:loss = 0.011636932, step = 36101 (0.324 sec)
# INFO:tensorflow:global_step/sec: 308.82
# INFO:tensorflow:loss = 0.018871466, step = 36201 (0.325 sec)
# INFO:tensorflow:global_step/sec: 297.791
# INFO:tensorflow:loss = 0.0063564354, step = 36301 (0.335 sec)
# INFO:tensorflow:global_step/sec: 262.616
# INFO:tensorflow:loss = 0.009504318, step = 36401 (0.381 sec)
# INFO:tensorflow:global_step/sec: 282.648
# INFO:tensorflow:loss = 0.039306246, step = 36501 (0.354 sec)
# INFO:tensorflow:global_step/sec: 305.052
# INFO:tensorflow:loss = 0.013517313, step = 36601 (0.327 sec)
# INFO:tensorflow:global_step/sec: 306.924
# INFO:tensorflow:loss = 0.022520568, step = 36701 (0.326 sec)
# INFO:tensorflow:global_step/sec: 311.702
# INFO:tensorflow:loss = 0.007569881, step = 36801 (0.324 sec)
# INFO:tensorflow:global_step/sec: 310.738
# INFO:tensorflow:loss = 0.009286598, step = 36901 (0.320 sec)
# INFO:tensorflow:global_step/sec: 313.661
# INFO:tensorflow:loss = 0.080708764, step = 37001 (0.318 sec)
# INFO:tensorflow:global_step/sec: 316.635
# INFO:tensorflow:loss = 0.028070025, step = 37101 (0.316 sec)
# INFO:tensorflow:global_step/sec: 299.573
# INFO:tensorflow:loss = 0.0060724905, step = 37201 (0.334 sec)
# INFO:tensorflow:global_step/sec: 313.66
# INFO:tensorflow:loss = 0.014565912, step = 37301 (0.319 sec)
# INFO:tensorflow:global_step/sec: 303.203
# INFO:tensorflow:loss = 0.026503686, step = 37401 (0.331 sec)
# INFO:tensorflow:global_step/sec: 261.929
# INFO:tensorflow:loss = 0.024665147, step = 37501 (0.382 sec)
# INFO:tensorflow:global_step/sec: 290.864
# INFO:tensorflow:loss = 0.008522366, step = 37601 (0.344 sec)
# INFO:tensorflow:global_step/sec: 309.775
# INFO:tensorflow:loss = 0.035612132, step = 37701 (0.322 sec)
# INFO:tensorflow:global_step/sec: 313.656
# INFO:tensorflow:loss = 0.033741776, step = 37801 (0.320 sec)
# INFO:tensorflow:global_step/sec: 314.65
# INFO:tensorflow:loss = 0.098513946, step = 37901 (0.317 sec)
# INFO:tensorflow:global_step/sec: 316.636
# INFO:tensorflow:loss = 0.0039267414, step = 38001 (0.317 sec)
# INFO:tensorflow:global_step/sec: 317.641
# INFO:tensorflow:loss = 0.012090231, step = 38101 (0.314 sec)
# INFO:tensorflow:global_step/sec: 309.775
# INFO:tensorflow:loss = 0.017174866, step = 38201 (0.324 sec)
# INFO:tensorflow:global_step/sec: 314.647
# INFO:tensorflow:loss = 0.028272625, step = 38301 (0.317 sec)
# INFO:tensorflow:global_step/sec: 316.636
# INFO:tensorflow:loss = 0.010637571, step = 38401 (0.317 sec)
# INFO:tensorflow:global_step/sec: 287.521
# INFO:tensorflow:loss = 0.01467517, step = 38501 (0.351 sec)
# INFO:tensorflow:global_step/sec: 260.565
# INFO:tensorflow:loss = 0.0316329, step = 38601 (0.381 sec)
# INFO:tensorflow:global_step/sec: 307.868
# INFO:tensorflow:loss = 0.017744789, step = 38701 (0.324 sec)
# INFO:tensorflow:global_step/sec: 305.986
# INFO:tensorflow:loss = 0.0016748887, step = 38801 (0.327 sec)
# INFO:tensorflow:global_step/sec: 306.924
# INFO:tensorflow:loss = 0.026879612, step = 38901 (0.326 sec)
# INFO:tensorflow:global_step/sec: 312.679
# INFO:tensorflow:loss = 0.002825636, step = 39001 (0.321 sec)
# INFO:tensorflow:global_step/sec: 309.774
# INFO:tensorflow:loss = 0.013494415, step = 39101 (0.323 sec)
# INFO:tensorflow:global_step/sec: 296.028
# INFO:tensorflow:loss = 0.0009228169, step = 39201 (0.337 sec)
# INFO:tensorflow:global_step/sec: 310.737
# INFO:tensorflow:loss = 0.014490133, step = 39301 (0.322 sec)
# INFO:tensorflow:global_step/sec: 312.678
# INFO:tensorflow:loss = 0.003362064, step = 39401 (0.320 sec)
# INFO:tensorflow:global_step/sec: 305.053
# INFO:tensorflow:loss = 0.04338023, step = 39501 (0.328 sec)
# INFO:tensorflow:global_step/sec: 259.216
# INFO:tensorflow:loss = 0.007867888, step = 39601 (0.387 sec)
# INFO:tensorflow:global_step/sec: 257.216
# INFO:tensorflow:loss = 0.023370536, step = 39701 (0.389 sec)
# INFO:tensorflow:global_step/sec: 305.052
# INFO:tensorflow:loss = 0.0021050232, step = 39801 (0.327 sec)
# INFO:tensorflow:global_step/sec: 307.869
# INFO:tensorflow:loss = 0.02911074, step = 39901 (0.325 sec)
# INFO:tensorflow:global_step/sec: 299.573
# INFO:tensorflow:loss = 0.00078155927, step = 40001 (0.334 sec)
# INFO:tensorflow:global_step/sec: 296.906
# INFO:tensorflow:loss = 0.004766836, step = 40101 (0.338 sec)
# INFO:tensorflow:global_step/sec: 305.051
# INFO:tensorflow:loss = 0.023831312, step = 40201 (0.327 sec)
# INFO:tensorflow:global_step/sec: 298.679
# INFO:tensorflow:loss = 0.010768136, step = 40301 (0.336 sec)
# INFO:tensorflow:global_step/sec: 277.936
# INFO:tensorflow:loss = 0.02719651, step = 40401 (0.359 sec)
# INFO:tensorflow:global_step/sec: 293.177
# INFO:tensorflow:loss = 0.02909667, step = 40501 (0.342 sec)
# INFO:tensorflow:global_step/sec: 283.445
# INFO:tensorflow:loss = 0.00999298, step = 40601 (0.353 sec)
# INFO:tensorflow:global_step/sec: 269.698
# INFO:tensorflow:loss = 0.015468199, step = 40701 (0.371 sec)
# INFO:tensorflow:global_step/sec: 263.308
# INFO:tensorflow:loss = 0.011007725, step = 40801 (0.379 sec)
# INFO:tensorflow:global_step/sec: 306.922
# INFO:tensorflow:loss = 0.00020359816, step = 40901 (0.327 sec)
# INFO:tensorflow:global_step/sec: 307.87
# INFO:tensorflow:loss = 0.08769333, step = 41001 (0.324 sec)
# INFO:tensorflow:global_step/sec: 305.052
# INFO:tensorflow:loss = 0.042994045, step = 41101 (0.328 sec)
# INFO:tensorflow:global_step/sec: 290.864
# INFO:tensorflow:loss = 0.057795696, step = 41201 (0.344 sec)
# INFO:tensorflow:global_step/sec: 300.473
# INFO:tensorflow:loss = 0.048708417, step = 41301 (0.333 sec)
# INFO:tensorflow:global_step/sec: 303.204
# INFO:tensorflow:loss = 0.041317504, step = 41401 (0.330 sec)
# INFO:tensorflow:global_step/sec: 319.671
# INFO:tensorflow:loss = 0.0045223865, step = 41501 (0.315 sec)
# INFO:tensorflow:global_step/sec: 315.637
# INFO:tensorflow:loss = 0.032584872, step = 41601 (0.315 sec)
# INFO:tensorflow:global_step/sec: 296.028
# INFO:tensorflow:loss = 0.026558138, step = 41701 (0.339 sec)
# INFO:tensorflow:global_step/sec: 262.617
# INFO:tensorflow:loss = 0.026443962, step = 41801 (0.381 sec)
# INFO:tensorflow:global_step/sec: 268.971
# INFO:tensorflow:loss = 0.03169131, step = 41901 (0.371 sec)
# INFO:tensorflow:global_step/sec: 308.818
# INFO:tensorflow:loss = 0.01790867, step = 42001 (0.324 sec)
# INFO:tensorflow:global_step/sec: 318.653
# INFO:tensorflow:loss = 0.0152394, step = 42101 (0.314 sec)
# INFO:tensorflow:global_step/sec: 314.646
# INFO:tensorflow:loss = 0.026577417, step = 42201 (0.318 sec)
# INFO:tensorflow:global_step/sec: 314.646
# INFO:tensorflow:loss = 0.12125861, step = 42301 (0.319 sec)
# INFO:tensorflow:global_step/sec: 317.642
# INFO:tensorflow:loss = 0.0232108, step = 42401 (0.315 sec)
# INFO:tensorflow:global_step/sec: 310.736
# INFO:tensorflow:loss = 0.0049465625, step = 42501 (0.322 sec)
# INFO:tensorflow:global_step/sec: 318.655
# INFO:tensorflow:loss = 0.020478416, step = 42601 (0.314 sec)
# INFO:tensorflow:global_step/sec: 314.645
# INFO:tensorflow:loss = 0.01595322, step = 42701 (0.317 sec)
# INFO:tensorflow:global_step/sec: 309.774
# INFO:tensorflow:loss = 0.018952638, step = 42801 (0.323 sec)
# INFO:tensorflow:global_step/sec: 263.309
# INFO:tensorflow:loss = 0.0024844366, step = 42901 (0.381 sec)
# INFO:tensorflow:global_step/sec: 285.878
# INFO:tensorflow:loss = 0.038171377, step = 43001 (0.350 sec)
# INFO:tensorflow:global_step/sec: 310.737
# INFO:tensorflow:loss = 0.013620295, step = 43101 (0.321 sec)
# INFO:tensorflow:global_step/sec: 308.817
# INFO:tensorflow:loss = 0.019763667, step = 43201 (0.325 sec)
# INFO:tensorflow:global_step/sec: 310.738
# INFO:tensorflow:loss = 0.0010194365, step = 43301 (0.321 sec)
# INFO:tensorflow:global_step/sec: 310.735
# INFO:tensorflow:loss = 0.0024939901, step = 43401 (0.326 sec)
# INFO:tensorflow:global_step/sec: 314.647
# INFO:tensorflow:loss = 0.007205924, step = 43501 (0.314 sec)
# INFO:tensorflow:global_step/sec: 311.705
# INFO:tensorflow:loss = 0.00799268, step = 43601 (0.322 sec)
# INFO:tensorflow:global_step/sec: 314.646
# INFO:tensorflow:loss = 0.020351749, step = 43701 (0.318 sec)
# INFO:tensorflow:global_step/sec: 308.818
# INFO:tensorflow:loss = 0.013508269, step = 43801 (0.323 sec)
# INFO:tensorflow:global_step/sec: 296.027
# INFO:tensorflow:loss = 0.009314031, step = 43901 (0.339 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into C:\Users\jongm\AppData\Local\Temp\tmp16z4p7tg\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.013671358.

# %%
# Test input function
test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_test}, y=y_test, shuffle=False)

# Test
eval_results = dnn_clf.evaluate(input_fn=test_input_fn)
eval_results
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-12-17:43:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\jongm\AppData\Local\Temp\tmp16z4p7tg\model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-12-17:43:39
# INFO:tensorflow:Saving dict for global step 44000: accuracy = 0.98, average_loss = 0.10493586, global_step = 44000, loss = 13.283021
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: C:\Users\jongm\AppData\Local\Temp\tmp16z4p7tg\model.ckpt-44000
# {'accuracy': 0.98,
#  'average_loss': 0.10493586,
#  'loss': 13.283021,
#  'global_step': 44000}

# %% [markdown]
# ## 10.3 텐서플로의 저수준 API로 심층 신경망 학습하기
#
# 아래의 예제는 위에서 MNIST 분류기를 `Estimator`로 구현한 것을 이번에는 텐서플로 Low-Level로 구현한 것이다.

# %%
import tensorflow as tf

# MNIST Dataset Load!
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# reshape : 28 x 28 -> 784
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

# split validation set
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
reset_graph()

################
# layer params #
################
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

inputs = tf.placeholder(tf.float32, shape=[None, n_inputs], name="inputs")
labels = tf.placeholder(tf.int32, shape=[None], name="outputs")

# %%
def neuron_layer(inputs, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(inputs.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal([n_inputs, n_neurons], stddev=stddev)
        weights = tf.Variable(init, name="weights")
        bias = tf.Variable(tf.zeros([n_neurons]), name='bias')
        Z = tf.matmul(inputs, weights) + bias
        if activation:
            return activation(Z)
        else:
            return Z

# %%
with tf.name_scope('dnn'):
    hidden1 = neuron_layer(inputs, n_hidden1, name='hidden1', 
                           activation=tf.nn.relu)
    hidden2 = neuron_layer(hidden1, n_hidden2, name='hidden2',
                           activation=tf.nn.relu)
    logits = neuron_layer(hidden2, n_outputs, name='logits')

# %%
with tf.name_scope('loss'):
    cross_entropy = tf.reduce_mean(
        tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits))

# %%
################
# Hyper-params #
################
learning_rate = 0.01
n_epochs = 40
batch_size = 50

with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    train_op = optimizer.minimize(cross_entropy)

with tf.name_scope('eval'):
    correct = tf.nn.in_top_k(predictions=logits, targets=labels, k=1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
# train
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(train_op, feed_dict={inputs: X_batch,
                                          labels: y_batch})
        
        acc_batch = accuracy.eval(feed_dict={inputs: X_batch, labels: y_batch})
        acc_valid = accuracy.eval(feed_dict={inputs: X_valid, labels: y_valid})
        print('epoch: {:03d}, bacth acc: {:.4f}, valid acc: {:.4f}'.format(epoch,
                                                                          acc_batch,
                                                                          acc_valid))
# Out:
# epoch: 000, bacth acc: 0.9000, valid acc: 0.9164
# epoch: 001, bacth acc: 0.9000, valid acc: 0.9364
# epoch: 002, bacth acc: 0.9000, valid acc: 0.9476
# epoch: 003, bacth acc: 0.9600, valid acc: 0.9526
# epoch: 004, bacth acc: 0.9600, valid acc: 0.9528
# epoch: 005, bacth acc: 0.9600, valid acc: 0.9586
# epoch: 006, bacth acc: 1.0000, valid acc: 0.9612
# epoch: 007, bacth acc: 0.9400, valid acc: 0.9632
# epoch: 008, bacth acc: 1.0000, valid acc: 0.9638
# epoch: 009, bacth acc: 1.0000, valid acc: 0.9660
# epoch: 010, bacth acc: 1.0000, valid acc: 0.9684
# epoch: 011, bacth acc: 0.9800, valid acc: 0.9698
# epoch: 012, bacth acc: 1.0000, valid acc: 0.9698
# epoch: 013, bacth acc: 1.0000, valid acc: 0.9706
# epoch: 014, bacth acc: 0.9800, valid acc: 0.9710
# epoch: 015, bacth acc: 0.9800, valid acc: 0.9734
# epoch: 016, bacth acc: 0.9800, valid acc: 0.9722
# epoch: 017, bacth acc: 0.9800, valid acc: 0.9742
# epoch: 018, bacth acc: 0.9400, valid acc: 0.9752
# epoch: 019, bacth acc: 1.0000, valid acc: 0.9752
# epoch: 020, bacth acc: 0.9400, valid acc: 0.9746
# epoch: 021, bacth acc: 0.9400, valid acc: 0.9756
# epoch: 022, bacth acc: 0.9800, valid acc: 0.9750
# epoch: 023, bacth acc: 0.9600, valid acc: 0.9762
# epoch: 024, bacth acc: 0.9600, valid acc: 0.9774
# epoch: 025, bacth acc: 0.9800, valid acc: 0.9792
# epoch: 026, bacth acc: 1.0000, valid acc: 0.9768
# epoch: 027, bacth acc: 0.9800, valid acc: 0.9776
# epoch: 028, bacth acc: 0.9800, valid acc: 0.9786
# epoch: 029, bacth acc: 1.0000, valid acc: 0.9774
# epoch: 030, bacth acc: 0.9800, valid acc: 0.9792
# epoch: 031, bacth acc: 1.0000, valid acc: 0.9782
# epoch: 032, bacth acc: 0.9800, valid acc: 0.9782
# epoch: 033, bacth acc: 0.9800, valid acc: 0.9786
# epoch: 034, bacth acc: 1.0000, valid acc: 0.9786
# epoch: 035, bacth acc: 1.0000, valid acc: 0.9802
# epoch: 036, bacth acc: 1.0000, valid acc: 0.9792
# epoch: 037, bacth acc: 1.0000, valid acc: 0.9784
# epoch: 038, bacth acc: 0.9800, valid acc: 0.9798
# epoch: 039, bacth acc: 1.0000, valid acc: 0.9780

# %% [markdown]
# ### `neuron_layer()` 대신 `tf.layers.dense()` 사용

# %%
import tensorflow as tf

# MNIST Dataset Load!
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# reshape : 28 x 28 -> 784
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

# split validation set
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
reset_graph()

################
# layer params #
################
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

inputs = tf.placeholder(tf.float32, shape=[None, n_inputs], name="inputs")
labels = tf.placeholder(tf.int32, shape=[None], name="outputs")

# %%
with tf.name_scope('dnn'):
    hidden1 = tf.layers.dense(inputs=inputs, units=n_hidden1,
                              activation=tf.nn.relu, name='hidden1',
                              kernel_initializer=tf.truncated_normal_initializer(stddev=0.1))
    hidden2 = tf.layers.dense(hidden1, n_hidden2,
                              activation=tf.nn.relu, name='hidden2',
                              kernel_initializer=tf.truncated_normal_initializer(stddev=0.1))
    logits = tf.layers.dense(hidden2, n_outputs, name='logits')

# %%
with tf.name_scope('loss'):
    cross_entropy = tf.reduce_mean(
        tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits))

# %%
################
# Hyper-params #
################
learning_rate = 0.01
n_epochs = 40
batch_size = 50

with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    train_op = optimizer.minimize(cross_entropy)

with tf.name_scope('eval'):
    correct = tf.nn.in_top_k(predictions=logits, targets=labels, k=1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
# train
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(train_op, feed_dict={inputs: X_batch,
                                          labels: y_batch})
        
        acc_batch = accuracy.eval(feed_dict={inputs: X_batch, labels: y_batch})
        acc_valid = accuracy.eval(feed_dict={inputs: X_valid, labels: y_valid})
        print('epoch: {:03d}, bacth acc: {:.4f}, valid acc: {:.4f}'.format(epoch,
                                                                          acc_batch,
                                                                          acc_valid))
# Out:
# epoch: 000, bacth acc: 0.8600, valid acc: 0.9106
# epoch: 001, bacth acc: 0.9200, valid acc: 0.9256
# epoch: 002, bacth acc: 0.9600, valid acc: 0.9358
# epoch: 003, bacth acc: 0.9000, valid acc: 0.9418
# epoch: 004, bacth acc: 0.9600, valid acc: 0.9458
# epoch: 005, bacth acc: 0.9600, valid acc: 0.9484
# epoch: 006, bacth acc: 1.0000, valid acc: 0.9544
# epoch: 007, bacth acc: 0.9400, valid acc: 0.9582
# epoch: 008, bacth acc: 0.9600, valid acc: 0.9592
# epoch: 009, bacth acc: 0.9600, valid acc: 0.9624
# epoch: 010, bacth acc: 0.9400, valid acc: 0.9660
# epoch: 011, bacth acc: 0.9800, valid acc: 0.9640
# epoch: 012, bacth acc: 0.9800, valid acc: 0.9632
# epoch: 013, bacth acc: 0.9800, valid acc: 0.9662
# epoch: 014, bacth acc: 1.0000, valid acc: 0.9668
# epoch: 015, bacth acc: 0.9400, valid acc: 0.9678
# epoch: 016, bacth acc: 0.9800, valid acc: 0.9706
# epoch: 017, bacth acc: 1.0000, valid acc: 0.9682
# epoch: 018, bacth acc: 0.9800, valid acc: 0.9706
# epoch: 019, bacth acc: 0.9800, valid acc: 0.9706
# epoch: 020, bacth acc: 1.0000, valid acc: 0.9710
# epoch: 021, bacth acc: 1.0000, valid acc: 0.9720
# epoch: 022, bacth acc: 0.9600, valid acc: 0.9716
# epoch: 023, bacth acc: 0.9800, valid acc: 0.9728
# epoch: 024, bacth acc: 0.9800, valid acc: 0.9728
# epoch: 025, bacth acc: 1.0000, valid acc: 0.9732
# epoch: 026, bacth acc: 0.9400, valid acc: 0.9724
# epoch: 027, bacth acc: 1.0000, valid acc: 0.9728
# epoch: 028, bacth acc: 0.9400, valid acc: 0.9720
# epoch: 029, bacth acc: 0.9600, valid acc: 0.9738
# epoch: 030, bacth acc: 0.9800, valid acc: 0.9720
# epoch: 031, bacth acc: 0.9800, valid acc: 0.9734
# epoch: 032, bacth acc: 0.9600, valid acc: 0.9746
# epoch: 033, bacth acc: 0.9800, valid acc: 0.9736
# epoch: 034, bacth acc: 0.9800, valid acc: 0.9740
# epoch: 035, bacth acc: 0.9800, valid acc: 0.9730
# epoch: 036, bacth acc: 0.9800, valid acc: 0.9726
# epoch: 037, bacth acc: 1.0000, valid acc: 0.9742
# epoch: 038, bacth acc: 0.9800, valid acc: 0.9742
# epoch: 039, bacth acc: 1.0000, valid acc: 0.9736

# %%
import graphviz
import tfgraphviz as tfg

tf_graph = tfg.board(tf.get_default_graph())
tf_graph

# %% [markdown]
# ## 10.4 신경망 하이퍼파라미터 튜닝하기

# %% [markdown]
# ### 10.4.1 은닉층의 수
#
# 1989년 George Cybenko는 뉴런 수만 무한하다면 은닉층 하나로 어떠한 함수도 근사할 수 있다는 것을 밝혔는데, 이를 **시벤코 정리**(Cybenko's theorem)이라고 한다. 실제로도 많은 문제들이 하나의 은닉층에 뉴런 수만 충분하다면 모델링이 가능하다. 하지만, 심층 신경망(DNN)이 얕은 신경망보다 **파라미터 효율성**이 훨씬 좋으며 복잡한 함수를 모델링하는 데에 있어 얕은 신경망보다 훨씬 적은 수의 뉴런을 사용하기 때문에 학습 시간이 더 빠르다.

# %% [markdown]
# ### 10.4.2 은닉층의 뉴런 수
#
# 위의 MNIST 분류기 예제 코드에서는 은닉층(hidden layer)의 뉴런수를 첫 번째 은닉층(`hidden1`)은 300개, 두 번째 은닉층(`hidden2`)은 100개로 구성하였다. 이처럼 은닉층의 뉴런 수는 일반적으로 각 층의 뉴런을 점점 줄여가는 방법으로 모델링한다. 그 이유는 저수준의 많은 특성(ex. 눈, 코, 입)이 고수준의 적은 특성(ex.얼굴 전체) 으로 합쳐질 수 있기 때문이다.
#
# 하지만, 요즘에는 모든 은닉층에 동일한 뉴런 수를 사용하며 모델이 오버피팅되기 전까지 점진적으로 뉴런 수를 늘린다. 일반적으로 층의 뉴런 수를 늘리는 것보다 층(layer) 개수를 늘리는 것이 성능이 더 좋아진다.
#
# 이처럼 최적의 은닉층의 수와 뉴런 수를 찾기란 매우 어려운 일이다. 따라서 실제 필요한 개수 보다 더 많은 층과 뉴런으로 모델링한 후에 오버피팅 되지않도록 조정해나가는 방식을 사용하는 데 이를 '스트레치 팬츠'(stratch pants) 방식이라고 한다(교재에서는 그 이유를 자신에게 알맞는 바지 사이즈를 찾는 데 시간을 낭비하는 대신, 큰 스트레치 팬츠를 사고 알맞게 줄이는게 더 낫기 때문).
